# %% [markdown]
# #**PROBLEMA DE NEGOCIO**
#
#
# ---

# %% [markdown]
# ##Una cadena de Supermercados Online que opera en Brasil quiere obtener insights sobre la venta de sus productos. Se deberá analizar los pedidos de sus clientes y mostrar gráficamente las respuestas de las siguientes preguntas de negocio:

# %% [markdown]
# ### **Preguntas**
#
# 1. ¿Cuáles son las ventas totales por año? ¿Y qué año tuvo mejor desempeño?
#
# 2. ¿Cuáles son los 7 productos que más ganancias mostraron durante todo el período?
#
# 3. Si separamos las ventas totales por año y por regiones ¿Qué insight podemos obtener de nuestras ventas?
#
# 4. Si separamos las ventas totales por año y por regiones ¿Qué insight podemos obtener de nuestras ventas?
#
# 5. ¿Cuáles son las ventas totales por trimestre en el estado de São Paulo?
#
# 6. ¿Top 10 clientes que mas han gastado?

# %% [markdown]
# ## 1. Configuración del ambiente

# %%
# !python -V
print('------')
# !pip show Pandas | grep 'Name\|Version'
print('------')
# !pip show Matplotlib | grep 'Name\|Version'
# Out:
# /bin/bash: python: command not found
# ------
# Name: pandas
# Version: 2.0.3
# ------
# Name: matplotlib
# Version: 3.7.5

# %% [markdown]
# ### Importar librerias

# %%
import pandas as pd 
import matplotlib.pyplot as plt  
import matplotlib.dates as mdates
import seaborn as sns
global df_ventas, df_ventas_limpio

# %% [markdown]
# ### El data set tiene inicialmente 8954 filas y 17 columnas. Se debe analizar una cadena de Supermercados Online que opera en Brasil quiere obtener insights sobre la venta de sus productos.
#
#
# 1. **fecha_pedido:** Fecha en la que se realizó el pedido.
# 2. **fecha_envio:** Fecha en la que se envió el pedido.
# 3. **modo_envio:** Modo de envío seleccionado para el pedido (por ejemplo, Económico, Entrega estándar, Envío rápido, 24 horas, etc.).
# 4. **nombre_cliente:** Nombre del cliente que realizó el pedido.
# 5. **segmento_cliente:** Segmento al que pertenece el cliente (por ejemplo, B2C para consumidor final, B2B para negocio a negocio).
# 6. **ciudad:** Ciudad de residencia del cliente.
# 7. **estado:** Estado o provincia donde se encuentra la ciudad del cliente.
# 8. **region:** Región geográfica a la que pertenece el estado del cliente (por ejemplo, Sureste, Nordeste).
# 9. departamento_producto: Categoría principal del producto.
# 10. **tipo_producto:** Tipo específico de producto.
# 11. **precio_base:** Precio base del producto antes de aplicar descuentos.
# 12. **precio_unit_sin_desc:** Precio unitario del producto sin descuentos aplicados.
# 13. **descuento:** Porcentaje de descuento aplicado al producto.
# 14. **precio_unit_venta:** Precio unitario final del producto después de aplicar descuentos.
# 15. **cantidad_pedido:** Cantidad de unidades del producto pedidas.
# 16. **total_venta:** Total de ventas generadas por el pedido.
# 17. **total_ganancia:** Ganancia total generada por el pedido.

# %% [markdown]
# ## 2. Obtención de datos

# %% [markdown]
# ### 2.1 Leer el archivo csv

# %%
df_ventas = pd.read_csv("reporte_ventas.csv", sep=",")
print('Informacion:')
print(df_ventas.info())
print('------------')
print('Duplicados:')
print(df_ventas.duplicated().sum())
print('------------')
print('Registros de pruebas:')
print((df_ventas['nombre_cliente'] == 'prueba').sum())
print('------------')
print('Registros con ganancias <=0')
print((df_ventas['total_ganancia'] <=0).sum())
# Out:
# Informacion:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8954 entries, 0 to 8953
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_pedido           8954 non-null   object
#  1   fecha_envio            8954 non-null   object
#  2   modo_envio             8954 non-null   object
#  3   nombre_cliente         8952 non-null   object
#  4   segmento_cliente       8954 non-null   object
#  5   ciudad                 8954 non-null   object
#  6   estado                 8954 non-null   object
#  7   region                 8954 non-null   object
#  8   departamento_producto  8954 non-null   object
#  9   tipo_producto          8954 non-null   object
#  10  precio_base            8954 non-null   float64
#  11  precio_unit_sin_desc   8954 non-null   float64
#  12  descuento              8954 non-null   float64
#  13  precio_unit_venta      8954 non-null   float64
#  14  cantidad_pedido        8954 non-null   int64
#  15  total_venta            8954 non-null   float64
#  16  total_ganancia         8954 non-null   float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 1.2+ MB
# None
# ------------
# Duplicados:
# 15
# ------------
# Registros de pruebas:
# 4
# ------------
# Registros con ganancias <=0
# 1726

# %%
df_ventas
# Out:
#      fecha_pedido fecha_envio        modo_envio          nombre_cliente  \
# 0      2021-11-09  2021-11-12         Económico         Thiago Silveira
# 1      2021-11-09  2021-11-12         Económico         Thiago Silveira
# 2      2021-06-13  2021-06-17         Económico           Giovanna Lima
# 3      2020-10-12  2020-10-19  Entrega estándar       Ana Júlia da Cruz
# 4      2020-10-12  2020-10-19  Entrega estándar       Ana Júlia da Cruz
# ...           ...         ...               ...                     ...
# 8949   2020-06-19  2020-06-21      Envío rápido          Isabel Almeida
# 8950   2020-06-19  2020-06-21      Envío rápido          Isabel Almeida
# 8951   2021-12-04  2021-12-07      Envío rápido              Isis Alves
# 8952   2021-06-15  2021-06-15          24 horas  Gustavo Henrique Porto
# 8953   2021-09-03  2021-09-05      Envío rápido            Thales Pires
#
#      segmento_cliente          ciudad          estado   region  \
# 0                 B2C  Ribeirão Preto       São Paulo  Sureste
# 1                 B2C  Ribeirão Preto       São Paulo  Sureste
# 2                 B2B  Rio de Janeiro  Rio de Janeiro  Sureste
# 3                 B2C   Foz do Iguaçu          Paraná      Sur
# 4                 B2C   Foz do Iguaçu          Paraná      Sur
# ...               ...             ...             ...      ...
# 8949              B2B     São Vicente       São Paulo  Sureste
# 8950              B2B     São Vicente       São Paulo  Sureste
# 8951              B2C  Rio de Janeiro  Rio de Janeiro  Sureste
# 8952              B2B  Rio de Janeiro  Rio de Janeiro  Sureste
# 8953              B2B        Salvador           Bahia  Noreste
#
#       departamento_producto             tipo_producto  precio_base  \
# 0                      Ropa                 Camisetas       409.70
# 1                      Ropa                     Jeans       705.10
# 2     Productos de Limpieza  Toallitas desinfectantes        19.02
# 3                      Ropa                Zapatillas       781.38
# 4     Productos de Limpieza           Papel higiénico        35.88
# ...                     ...                       ...          ...
# 8949                   Ropa                     Jeans       522.75
# 8950  Productos de Limpieza          Bolsas de basura        14.54
# 8951                   Ropa                  Vestidos        48.83
# 8952                   Ropa                 Camisetas       395.45
# 8953  Productos de Limpieza           Papel higiénico        45.88
#
#       precio_unit_sin_desc  descuento  precio_unit_venta  cantidad_pedido  \
# 0                   445.33      0.000             445.33                2
# 1                   829.53      0.000             829.53                3
# 2                    24.86      0.000              24.86                2
# 3                   840.19      0.225             651.15                5
# 4                    42.24      0.100              38.02                2
# ...                    ...        ...                ...              ...
# 8949                607.40      0.100             546.66                4
# 8950                 19.58      0.100              17.62                4
# 8951                 63.41      0.000              63.41                6
# 8952                440.46      0.075             407.43                5
# 8953                 52.73      0.000              52.73                3
#
#       total_venta  total_ganancia
# 0          890.66           71.26
# 1         2488.59          373.29
# 2           49.72           11.68
# 3         3255.75         -651.15
# 4           76.04            4.28
# ...           ...             ...
# 8949      2186.64           95.64
# 8950        70.48           12.32
# 8951       380.46           87.48
# 8952      2037.15           59.90
# 8953       158.19           20.55
#
# [8954 rows x 17 columns]

# %% [markdown]
# ### 2. 2 Cambiar el formato de la columnas de fecha a un formato datetime

# %%
# Ver tipo de dato por columna
df_ventas.dtypes
# Out:
# fecha_pedido              object
# fecha_envio               object
# modo_envio                object
# nombre_cliente            object
# segmento_cliente          object
# ciudad                    object
# estado                    object
# region                    object
# departamento_producto     object
# tipo_producto             object
# precio_base              float64
# precio_unit_sin_desc     float64
# descuento                float64
# precio_unit_venta        float64
# cantidad_pedido            int64
# total_venta              float64
# total_ganancia           float64
# dtype: object

# %%
# cambiar el formato de las columnas fecha_pedido y fecha_envio a fecha 
df_ventas['fecha_pedido'] = pd.to_datetime(df_ventas['fecha_pedido'], format='%Y-%m-%d')
df_ventas['fecha_envio'] = pd.to_datetime(df_ventas['fecha_envio'], format='%Y-%m-%d')
df_ventas.dtypes
# Out:
# fecha_pedido             datetime64[ns]
# fecha_envio              datetime64[ns]
# modo_envio                       object
# nombre_cliente                   object
# segmento_cliente                 object
# ciudad                           object
# estado                           object
# region                           object
# departamento_producto            object
# tipo_producto                    object
# precio_base                     float64
# precio_unit_sin_desc            float64
# descuento                       float64
# precio_unit_venta               float64
# cantidad_pedido                   int64
# total_venta                     float64
# total_ganancia                  float64
# dtype: object

# %% [markdown]
# ### 2.3 Ver filas repetidas y Eliminar duplicados

# %%
duplicados = df_ventas.duplicated()
cantidad_duplicados = duplicados.sum()

print(f"Cantidad de datos duplicados: {cantidad_duplicados}")
# Out:
# Cantidad de datos duplicados: 15

# %%
# Vemos las filas donde estan los datos duplicados
duplicados = df_ventas[df_ventas.duplicated()]

print("Filas duplicadas:")
duplicados
# Out:
# Filas duplicadas:
#      fecha_pedido fecha_envio        modo_envio          nombre_cliente  \
# 3047   2019-04-24  2019-04-28  Entrega estándar         Murilo Nogueira
# 8940   2020-10-12  2020-10-19  Entrega estándar       Ana Júlia da Cruz
# 8941   2019-06-10  2019-06-15  Entrega estándar             Sophia Dias
# 8942   2019-06-10  2019-06-15  Entrega estándar             Sophia Dias
# 8943   2019-06-10  2019-06-15  Entrega estándar             Sophia Dias
# 8944   2022-06-05  2022-06-05          24 horas         Alice Rodrigues
# 8945   2022-06-05  2022-06-05          24 horas         Alice Rodrigues
# 8946   2020-04-08  2020-04-10      Envío rápido           Lucca Freitas
# 8947   2019-05-22  2019-05-27  Entrega estándar     Luiz Gustavo Araújo
# 8948   2020-06-19  2020-06-21      Envío rápido          Isabel Almeida
# 8949   2020-06-19  2020-06-21      Envío rápido          Isabel Almeida
# 8950   2020-06-19  2020-06-21      Envío rápido          Isabel Almeida
# 8951   2021-12-04  2021-12-07      Envío rápido              Isis Alves
# 8952   2021-06-15  2021-06-15          24 horas  Gustavo Henrique Porto
# 8953   2021-09-03  2021-09-05      Envío rápido            Thales Pires
#
#      segmento_cliente                   ciudad            estado  \
# 3047              B2B                 Curitiba            Paraná
# 8940              B2C            Foz do Iguaçu            Paraná
# 8941              B2C           Rio de Janeiro    Rio de Janeiro
# 8942              B2C           Rio de Janeiro    Rio de Janeiro
# 8943              B2C           Rio de Janeiro    Rio de Janeiro
# 8944              B2B  Cachoeiro de Itapemirim    Espírito Santo
# 8945              B2B  Cachoeiro de Itapemirim    Espírito Santo
# 8946              B2B                 Brasília  Distrito Federal
# 8947              B2B                  Aracaju           Sergipe
# 8948              B2B              São Vicente         São Paulo
# 8949              B2B              São Vicente         São Paulo
# 8950              B2B              São Vicente         São Paulo
# 8951              B2C           Rio de Janeiro    Rio de Janeiro
# 8952              B2B           Rio de Janeiro    Rio de Janeiro
# 8953              B2B                 Salvador             Bahia
#
#             region  departamento_producto          tipo_producto  precio_base  \
# 3047           Sur                   Ropa                  Jeans       488.58
# 8940           Sur  Productos de Limpieza        Papel higiénico        35.88
# 8941       Sureste                   Ropa               Vestidos        20.29
# 8942       Sureste  Productos de Limpieza  Limpiador de inodoros         5.35
# 8943       Sureste           Electrónicos      Cámaras digitales       488.35
# 8944       Sureste           Electrónicos           Lámparas LED        39.37
# 8945       Sureste           Electrónicos           Lámparas LED         8.33
# 8946  Centro-Oeste  Productos de Limpieza  Limpiador de inodoros        12.72
# 8947       Noreste           Electrónicos           Lámparas LED       164.24
# 8948       Sureste           Electrónicos           Lámparas LED         9.49
# 8949       Sureste                   Ropa                  Jeans       522.75
# 8950       Sureste  Productos de Limpieza       Bolsas de basura        14.54
# 8951       Sureste                   Ropa               Vestidos        48.83
# 8952       Sureste                   Ropa              Camisetas       395.45
# 8953       Noreste  Productos de Limpieza        Papel higiénico        45.88
#
#       precio_unit_sin_desc  descuento  precio_unit_venta  cantidad_pedido  \
# 3047                562.74      0.150             478.33                2
# 8940                 42.24      0.100              38.02                2
# 8941                 23.73      0.000              23.73                7
# 8942                  6.19      0.000               6.19                4
# 8943                571.17      0.100             514.05                6
# 8944                 52.50      0.000              52.50                7
# 8945                 10.81      0.000              10.81                3
# 8946                 14.78      0.100              13.30                3
# 8947                217.53      0.000             217.53                7
# 8948                 10.69      0.350               6.95                3
# 8949                607.40      0.100             546.66                4
# 8950                 19.58      0.100              17.62                4
# 8951                 63.41      0.000              63.41                6
# 8952                440.46      0.075             407.43                5
# 8953                 52.73      0.000              52.73                3
#
#       total_venta  total_ganancia
# 3047       956.66          -20.50
# 8940        76.04            4.28
# 8941       166.11           24.08
# 8942        24.76            3.36
# 8943      3084.30          154.20
# 8944       367.50           91.91
# 8945        32.43            7.44
# 8946        39.90            1.74
# 8947      1522.71          373.03
# 8948        20.85           -7.62
# 8949      2186.64           95.64
# 8950        70.48           12.32
# 8951       380.46           87.48
# 8952      2037.15           59.90
# 8953       158.19           20.55

# %% [markdown]
# ### Eliminamos duplicados

# %%
# Eliminamos duplicados
print(f'Tamaño del set antes de eliminar las filas repetidas: {df_ventas.shape}')
df_ventas_limpio = df_ventas.drop_duplicates(inplace=False)  # inplace=False para que devuelva un nuevo DataFrame
print(f'Tamaño del set después de eliminar las filas repetidas: {df_ventas_limpio.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (8954, 17)
# Tamaño del set después de eliminar las filas repetidas: (8939, 17)

# %% [markdown]
#  ### Errores tipográficos en variables categóricas

# %%
# Graficar los subnivelesde de las columnas categoricas
cols_categoricas = df_ventas_limpio.select_dtypes(include=['object']).columns

fig, ax = plt.subplots(nrows=len(cols_categoricas), ncols=1, figsize=(10,30))
fig.subplots_adjust(hspace=2)

for i, col in enumerate(cols_categoricas):
    sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
    ax[i].set_title(col)
    ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)

plt.show()
# Out:
# /tmp/ipykernel_224410/1971978782.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
# /tmp/ipykernel_224410/1971978782.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)
# /tmp/ipykernel_224410/1971978782.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
# /tmp/ipykernel_224410/1971978782.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)
# /tmp/ipykernel_224410/1971978782.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
# /tmp/ipykernel_224410/1971978782.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)
# /tmp/ipykernel_224410/1971978782.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
# /tmp/ipykernel_224410/1971978782.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)
# /tmp/ipykernel_224410/1971978782.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
# /tmp/ipykernel_224410/1971978782.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)
# /tmp/ipykernel_224410/1971978782.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
# /tmp/ipykernel_224410/1971978782.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)
# /tmp/ipykernel_224410/1971978782.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
# /tmp/ipykernel_224410/1971978782.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)
# /tmp/ipykernel_224410/1971978782.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df_ventas_limpio, ax=ax[i], palette='Set1')
# /tmp/ipykernel_224410/1971978782.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=70)

# %% [markdown]
# #### Veo con unique las dos columnas que no se ven bien su categorias

# %%
df_ventas_limpio['nombre_cliente'].unique()
# Out:
# array(['Thiago Silveira', 'Giovanna Lima', 'Ana Júlia da Cruz',
#        'Sophia Dias', 'prueba', 'Alana Ramos', 'Nicolas Rezende',
#        'Gabriel da Paz', 'Amanda Nascimento', 'Alice Ribeiro',
#        'Bianca Campos', 'Nicole Gomes', 'Melissa da Rosa',
#        'Felipe Rodrigues', 'Benjamin Moura', 'Luiz Henrique Rezende',
#        'Maria Eduarda Rodrigues', 'Heitor Silveira', 'Kaique Aragão',
#        'Lara Pinto', 'Alexandre Vieira', 'Diego Nascimento',
#        'João Pedro Silveira', 'Caroline Cavalcanti', 'Ana Beatriz Souza',
#        'Vitor Hugo Dias', 'Gustavo Henrique Almeida', 'Alexandre Mendes',
#        'Renan Santos', 'Marcela da Conceição', 'João Lucas Rocha',
#        'Mariane Costa', 'Sarah Oliveira', 'Ana Beatriz Barros',
#        'Benício da Mota', 'Vicente Novaes', 'João Lucas Ramos',
#        'Juan da Conceição', 'Fernando Farias', 'Vicente Nogueira',
#        'Arthur Cavalcanti', 'Alícia da Mota', 'Kevin das Neves',
#        'João Guilherme da Conceição', 'Maria Vitória Silveira',
#        'Caio Oliveira', 'Fernando da Cunha', 'Paulo Farias', 'Igor Sales',
#        'Catarina Duarte', 'Ana Sophia Teixeira', 'Maria Julia Nogueira',
#        'Pedro da Luz', 'André da Mota', 'Renan Carvalho', 'Lucas Azevedo',
#        'Breno Farias', 'Enrico Teixeira', 'Vinicius da Costa',
#        'Calebe Monteiro', 'Gabriela Pires', 'Thiago Dias',
#        'Pedro Miguel Rodrigues', 'Daniel Martins', 'Antônio Novaes',
#        'Pedro Miguel Viana', 'Rodrigo Vieira', 'Srta. Valentina Alves',
#        'Gabrielly Rocha', 'Davi Luiz Araújo', 'Miguel Correia',
#        'Isabelly Azevedo', 'Bianca Pereira', 'Stephany Fogaça',
#        'Daniel Silva', 'Ana Vitória Moreira', 'Gustavo das Neves',
#        'Lucca Freitas', 'Agatha Farias', 'Erick Pinto', 'Raul Nogueira',
#        'Renan Campos', 'Pedro Lucas Moura', 'Maria Luiza Monteiro',
#        'Ryan Duarte', 'Noah Silveira', 'João Miguel Novaes', 'Caio Jesus',
#        'Melissa Costela', 'Lucca Rodrigues', 'Breno Jesus',
#        'Isabel Nunes', 'Clarice Martins', 'Ana Carolina Correia',
#        'Mariane da Conceição', 'Lorena Correia', 'Ryan Farias',
#        'Diogo Correia', 'Fernando da Conceição', 'Diego Lima',
#        'Nathan Fogaça', 'Luiz Fernando Freitas', 'Theo Martins',
#        'André Cavalcanti', 'Maria Eduarda Teixeira', 'Laís Araújo',
#        'Alice da Luz', 'Raquel Farias', 'Igor da Cunha', 'Luna Barbosa',
#        'Camila Caldeira', 'Ana Carolina Costa', 'Maria Luiza da Cunha',
#        'Melissa Mendes', 'Ana Luiza Melo', 'Vitor Gabriel Santos',
#        'Matheus Oliveira', 'Arthur da Paz', 'Nicolas Mendes',
#        'Agatha Ramos', 'Maria Luiza Fernandes', 'Cauê Teixeira',
#        'Rodrigo Novaes', 'Bruna Carvalho', 'Beatriz Peixoto',
#        'Joana Moraes', 'Ana Julia Dias', 'João Guilherme Rodrigues',
#        'Lavínia Azevedo', 'Melissa da Rocha', 'Vinicius da Rosa',
#        'Gustavo Henrique Cavalcanti', 'Luana Campos',
#        'João Miguel Castro', 'Leandro Fogaça', 'Maysa Cunha',
#        'Henrique Gonçalves', 'Davi Lucca Silveira', 'Sofia Ramos',
#        'Amanda Vieira', 'Theo Aragão', 'Eduarda Azevedo',
#        'Lucca Fernandes', 'Luiz Miguel Peixoto', 'Pietra Rezende',
#        'Henrique das Neves', 'Emanuel Cardoso', 'Isabella Cunha',
#        'Danilo Barbosa', 'Lucas Gabriel Araújo', 'Julia Jesus',
#        'Sofia Mendes', 'Breno Costela', 'Eduarda Ramos',
#        'Maria Fernanda Rodrigues', 'Felipe Rocha', 'Daniela Fernandes',
#        'Maria Fernanda Dias', 'Miguel Santos', 'Ana Julia Pinto',
#        'Raquel Pires', 'Raquel Freitas', 'Eloah da Cruz', 'Calebe Campos',
#        'Samuel Nascimento', 'Joaquim Moreira', 'Anthony Sales',
#        'Luiz Otávio Porto', 'Joana Almeida', 'Vitor Gabriel Fernandes',
#        'Maysa Rezende', 'Natália Duarte', 'Isabel Viana', 'Yuri Vieira',
#        'João Miguel da Rocha', 'Milena Oliveira', 'Alana da Paz',
#        'Matheus da Mota', 'Rafaela Barbosa', 'Levi da Mata',
#        'Luiz Gustavo Ramos', 'Julia da Cruz', 'Miguel Moura',
#        'Luiz Gustavo Nascimento', 'Luiz Otávio Carvalho',
#        'Enzo Gabriel Barbosa', 'Alícia Peixoto', 'Maria da Costa',
#        'Emanuelly Rodrigues', 'Rafael Araújo', 'Pedro Miguel Melo',
#        'Larissa da Conceição', 'Maria Vitória Caldeira', 'Isis Ferreira',
#        'Anthony Lopes', 'Marcela Fernandes', 'Daniel da Cunha',
#        'Yuri Moreira', 'Augusto da Cruz', 'Gabriel Ribeiro',
#        'João Guilherme Costela', 'Davi Luiz das Neves',
#        'Alexandre Barbosa', 'Renan Silva', 'Emilly Monteiro',
#        'Lorena Novaes', 'Gustavo Santos', 'Emilly Peixoto',
#        'Isabel Moura', 'Nicolas Lima', 'Maria Vitória Porto',
#        'Ana Sophia Almeida', 'Brenda Viana', 'Marcos Vinicius Ribeiro',
#        'Kaique Rodrigues', 'Maria Luiza Gomes', 'Cecília Duarte',
#        'Samuel Silva', 'Gabrielly Ferreira', 'Larissa Rezende',
#        'Benício da Cunha', 'Ana Lívia da Conceição',
#        'Maria Clara Martins', 'Renan Souza', 'Cecília Carvalho',
#        'Ana Lívia Moreira', 'Theo Castro', 'João Pedro Melo',
#        'Isabella Sales', 'Pietra Caldeira', 'Francisco Mendes',
#        'Bárbara Novaes', 'Carlos Eduardo da Paz', 'Milena Vieira',
#        'Otávio da Cruz', 'Heitor da Cruz', 'Arthur Monteiro',
#        'Isaac Rodrigues', 'Evelyn Lopes', 'Pietra Jesus',
#        'Giovanna Pereira', 'Vitória Monteiro', 'Kamilly Novaes',
#        'Maria Julia Sales', 'Manuela Sales', 'Maria Alice da Cunha',
#        'Raul Sales', 'Yuri Costela', 'Maria Cecília Jesus',
#        'Carolina Fogaça', 'Laís Gonçalves', 'Kaique Ferreira',
#        'Noah Mendes', 'Henrique Carvalho', 'Cauê Souza',
#        'João Felipe Lopes', 'Igor da Rocha', 'Isabel Almeida',
#        'Matheus Monteiro', 'Lara Castro', 'Julia Gomes', 'Nina Santos',
#        'Henrique Costela', 'Pedro Miguel Martins', 'Beatriz Freitas',
#        'Pedro Miguel da Cruz', 'Rafaela Costela', 'Igor das Neves',
#        'Isaac Silveira', 'Esther Pinto', 'Marina da Luz',
#        'Otávio Peixoto', 'Benício Gonçalves', 'Pedro Lucas Souza',
#        'Luigi da Mata', 'Ana Carolina Rezende', 'Maria Sophia da Mota',
#        'Miguel das Neves', 'Gustavo da Cruz', 'Noah Peixoto',
#        'Luiz Gustavo Azevedo', 'Anthony Costa', 'Helena da Cruz',
#        'Olivia Carvalho', 'Luiz Henrique Peixoto', 'Enzo Gabriel Farias',
#        'Augusto Pinto', 'Gustavo Novaes', 'Lavínia Cardoso',
#        'Lucas Gabriel Jesus', 'Murilo Cardoso', 'Nicolas Moura',
#        'Luna Azevedo', 'Davi Ramos', 'Alice Rezende', 'Carolina Teixeira',
#        'Vitória da Mota', 'Isadora Ramos', 'Alice da Mota',
#        'Calebe Ribeiro', 'Daniela Monteiro', 'Milena Nascimento',
#        'Davi Lucca Costa', 'Vitor Hugo Moura', 'Milena Lopes',
#        'Elisa Viana', 'Rodrigo da Cruz', 'Matheus Moraes',
#        'Agatha da Mata', 'Ana Júlia Mendes', 'Vitor Oliveira',
#        'Elisa Araújo', 'Augusto Costa', 'Pietro Castro', 'Enzo Pires',
#        'Lívia Cardoso', 'Alexia Farias', 'Danilo Teixeira',
#        'Maria Cecília Martins', 'Caroline Souza',
#        'Enzo Gabriel Rodrigues', 'Nicolas Gomes', 'Kaique Azevedo',
#        'Bryan da Conceição', 'Beatriz Campos', 'Rafael Azevedo',
#        'Davi Lucas Correia', 'Gabrielly Campos', 'Theo Novaes',
#        'Alice Vieira', 'Joaquim Nogueira', 'Thiago Nogueira',
#        'Ian da Mata', 'Joana da Cruz', 'Gustavo Ribeiro', 'Renan Novaes',
#        'Juliana da Luz', 'Agatha Jesus', 'Gabriela Teixeira',
#        'Benício Araújo', 'Sofia Moura', 'Alice Rodrigues',
#        'Joaquim Aragão', 'Otávio Santos', 'Kaique Rocha',
#        'Breno Gonçalves', 'Milena Rezende', 'Enrico Araújo',
#        'Levi Mendes', 'Juan Teixeira', 'Luiz Gustavo da Costa',
#        'Isis Alves', 'Kamilly Rocha', 'Pedro Lucas Ramos',
#        'Rafael Barros', 'Juliana Souza', 'Júlia Ramos',
#        'Clarice da Conceição', 'Pedro Lucas Moreira', 'Sophia Carvalho',
#        'Melissa Martins', 'João Gabriel das Neves', 'Augusto Gomes',
#        'Maitê Peixoto', 'Vitor Gabriel Porto', 'Beatriz Nogueira',
#        'Juan da Cunha', 'Thales Almeida', 'Marina Sales',
#        'Luiz Fernando das Neves', 'Luiz Gustavo Rodrigues',
#        'João Lucas Campos', 'Rafaela Vieira', 'Daniel Pinto',
#        'Julia Teixeira', 'Esther Rodrigues', 'Emanuel da Cruz',
#        'Benício Cardoso', 'Emilly Aragão', 'Igor Castro', 'Cauê da Rocha',
#        'Bianca Lima', 'Cauê Martins', 'Enzo Peixoto',
#        'Vicente Cavalcanti', 'João das Neves', 'Fernando Martins',
#        'Igor Barros', 'Rafael Duarte', 'Luiz Gustavo Araújo',
#        'Joaquim Caldeira', 'Ana Luiza da Luz', 'Natália da Costa',
#        'Marcelo Ramos', 'Miguel da Luz', 'Diogo Teixeira',
#        'Maria Carvalho', 'Rafael Ribeiro', 'Paulo Costela',
#        'Pietro Rocha', 'Daniel Mendes', 'Otávio da Rosa', 'Pedro Farias',
#        'Emanuelly Carvalho', 'Benjamin da Mata', 'Breno Pires',
#        'Heitor da Mata', 'Thales Pires', 'Bárbara Moraes',
#        'Bárbara Araújo', 'Manuela Duarte', 'Maitê da Luz',
#        'Maria Alice Almeida', 'Giovanna Lopes', 'Fernando Sales',
#        'Marcelo Silveira', 'Luiz Miguel Ferreira', 'Kevin Monteiro',
#        'Marina Carvalho', 'Marcelo Rezende', 'Calebe Dias',
#        'Clarice Mendes', 'Sofia Freitas', 'Ana Lívia da Luz',
#        'Marcos Vinicius da Conceição', 'Esther Freitas', 'Amanda Melo',
#        'Henrique Caldeira', 'Srta. Alexia Costela',
#        'Sra. Gabriela das Neves', 'Vitor Gabriel Vieira', 'Isabel Araújo',
#        'Caio Mendes', 'Nina Nascimento', 'Rafaela Viana', 'Diego Cardoso',
#        'Beatriz Santos', 'Murilo Moraes', 'Ana Julia Melo',
#        'Murilo Monteiro', 'Carolina Martins', 'Emilly Martins',
#        'Juan Caldeira', 'Joaquim Barros', 'João Caldeira',
#        'Bianca Silveira', 'Alexia Fogaça', 'Daniel Silveira',
#        'Maria Luiza Cunha', 'Milena Nogueira',
#        'Marcos Vinicius Nascimento', 'Kaique Barbosa', 'Enrico da Luz',
#        'Sofia Viana', 'Ana Sophia da Mota', 'Ana Clara Nogueira',
#        'Nathan Pires', 'Thiago Ramos', 'Maria Luiza da Costa',
#        'Lavínia Moreira', 'Carolina Ribeiro', 'Lorenzo Dias',
#        'Guilherme da Paz', 'Eduarda Teixeira', 'Ana Sophia Caldeira',
#        'Bernardo Caldeira', 'Sophie Melo', 'Maria das Neves',
#        'Agatha da Rocha', 'Alícia Cardoso', 'Luiz Miguel Nunes',
#        'Maria da Luz', 'Lucas Gabriel Melo', 'Ana Luiza Santos',
#        'Marcela Moreira', 'Diogo Aragão', 'Luiz Fernando Campos',
#        'Sofia da Cunha', 'Maria Luiza Nogueira', 'Ana da Paz',
#        'Gabriela Cunha', 'Davi Luiz da Paz', 'Ana Lívia Dias',
#        'Ana Júlia Monteiro', 'Pietro Barros', 'Arthur Vieira',
#        'Maria Fernanda Freitas', 'Luigi da Mota', 'Lorenzo Almeida',
#        'Joaquim Rodrigues', 'Isaac da Conceição', 'Breno Lopes',
#        'Clara Pires', 'Bruno Ferreira', 'Arthur Teixeira',
#        'Luiz Fernando Moraes', 'Joaquim Nascimento',
#        'Lucas Gabriel Caldeira', 'Francisco Monteiro', 'Leonardo Cardoso',
#        'João Felipe Nascimento', 'Pietro da Rosa', 'Clara Pinto',
#        'Henrique Barbosa', 'Maria Sophia Costela', 'Lavínia Pereira',
#        'Ana Sophia Peixoto', 'Maria Fernanda Almeida', 'Kamilly Correia',
#        'Leonardo Pires', 'Guilherme Teixeira', 'Heitor Duarte',
#        'Joana Castro', 'Arthur Pereira', 'Bryan Ferreira',
#        'Brenda da Cruz', 'Carlos Eduardo Santos', 'Vitor da Paz',
#        'Thales Sales', 'Gabriel Rocha', 'Pedro Henrique Dias',
#        'João Vitor Cunha', 'Isabelly Teixeira', 'Maria Julia Oliveira',
#        'Maria Eduarda Peixoto', 'Maria Luiza Almeida', 'Helena da Mata',
#        'Breno da Conceição', 'Renan Castro', 'Larissa Nogueira',
#        'Ana Julia Araújo', 'Marcela Farias', 'Luiz Otávio Pires',
#        'Melissa Aragão', 'Juliana Cardoso', 'Vitor da Rocha',
#        'Augusto Barbosa', 'Stella Santos', 'João Lucas Jesus',
#        'João Felipe da Conceição', 'Davi Lucas da Mota', 'Enrique Santos',
#        'Pietro da Costa', 'Bernardo Fernandes', 'Pietra Almeida',
#        'Amanda Castro', 'Maria Cecília Peixoto', 'Afonso Novaes',
#        'Sofia Ribeiro', 'Sophie Santos', 'Igor Pereira',
#        'Maria Clara Almeida', 'Davi Caldeira', 'Daniela Cardoso',
#        'Igor Rodrigues', 'Alexandre Jesus', 'Alice Viana',
#        'Clara Monteiro', 'Nicole Araújo', 'Vitor Hugo Freitas',
#        'Miguel Silveira', 'Kamilly Araújo', 'Gabriel Nogueira',
#        'Arthur Campos', 'Mirla Ramos', 'Diogo Farias', 'Rodrigo Teixeira',
#        'Erick da Luz', 'Thiago Jesus', 'Bárbara Costa',
#        'Luiz Otávio Souza', 'Heloísa Gonçalves', 'Pietro Pereira',
#        'Bryan Mendes', 'Lavínia da Cunha', 'Otávio da Paz',
#        'Juan Gonçalves', 'Júlia Moura', 'Erick da Cruz',
#        'João Lucas Peixoto', 'Maria Vitória da Rosa', 'Leonardo Ferreira',
#        'Joaquim Porto', 'Cecília Melo', 'Ana Julia da Rocha',
#        'Carlos Eduardo Barbosa', 'Bruno Pires', 'Bernardo das Neves',
#        'Matheus Castro', 'Lucas Gabriel Santos', 'Vitor Gabriel Ramos',
#        'Maria Clara Gonçalves', 'Emanuel da Cunha', 'Ana Lívia Moura',
#        'Pedro Miguel Correia', 'João Guilherme Ferreira',
#        'Ana Sophia Barros', 'Joaquim Peixoto', 'Augusto Oliveira',
#        'Nathan Silveira', 'Daniel Nunes', 'André Viana',
#        'Sra. Laura Fogaça', 'Raul Moreira', 'Valentina Rezende',
#        'Laura Santos', 'Kamilly Porto', 'Laís Peixoto',
#        'Manuela da Conceição', 'Bruno Alves', 'Ana Clara Martins', nan,
#        'Sabrina da Cruz', 'Yasmin Teixeira', 'Srta. Caroline Farias',
#        'Vinicius Nunes', 'Letícia Costela', 'Enrico Alves',
#        'Alexia Ribeiro', 'Ana Luiza Correia', 'Joana Teixeira',
#        'Vitor da Costa', 'Evelyn Novaes', 'Lorenzo Costa',
#        'Leandro da Mota', 'Ana Júlia da Mota', 'Yuri Cardoso',
#        'Daniel Jesus', 'Gabrielly Monteiro', 'Ana Lívia Carvalho',
#        'Thomas Rezende', 'Otávio Correia', 'João Vitor da Mota',
#        'Otávio da Costa', 'Maria Alice Mendes', 'Luana Nogueira',
#        'Heloísa Almeida', 'Pedro Miguel Souza', 'Fernando Vieira',
#        'Maria Cecília da Mata', 'Nicole Alves', 'Guilherme da Mota',
#        'Carolina Gomes', 'Kamilly Almeida', 'Cecília Costela',
#        'Emanuel Cunha', 'Vitor Freitas', 'Yago Souza',
#        'Maria Sophia Alves', 'Murilo Nogueira', 'Rodrigo Viana',
#        'Guilherme Fernandes', 'Maitê da Paz', 'Luiz Miguel Duarte',
#        'Camila Souza', 'Maria Fernanda Melo', 'Kamilly Viana',
#        'Lorena Ramos', 'Lucas Gabriel Carvalho', 'Alexandre Farias',
#        'João Gabriel da Mota', 'Gabrielly Moreira', 'João Vitor Alves',
#        'Luiz Fernando Barbosa', 'Ana da Mata', 'Manuela Fernandes',
#        'Cauê Pinto', 'Melissa Melo', 'Caroline Viana',
#        'Luiz Gustavo Silveira', 'Valentina Gomes', 'Pedro Lucas Campos',
#        'Maria Alice Sales', 'Eduarda Barros', 'Nicole Lopes',
#        'Larissa Melo', 'Luana Moreira', 'Raquel Mendes',
#        'Davi Luiz Cardoso', 'Cauê das Neves', 'João Vitor Silva',
#        'Júlia Martins', 'Fernando Souza', 'Larissa Ferreira',
#        'Luiza Santos', 'João Miguel Costela', 'João Moraes',
#        'Kevin Peixoto', 'Julia da Costa', 'Sarah Cavalcanti',
#        'Maria Farias', 'Ana Vitória Vieira', 'Ana da Cruz',
#        'Arthur Nascimento', 'Enzo da Mata', 'Pedro Miguel Vieira',
#        'Mirella Araújo', 'Ana Cardoso', 'Lara Rezende', 'Ana Rezende',
#        'Ryan Araújo', 'Laís Silva', 'Vicente Costela', 'Daniela da Mota',
#        'Bianca Almeida', 'Eduarda Cunha', 'Maria Sophia Rocha',
#        'Heitor Monteiro', 'Bárbara Rocha', 'Marcos Vinicius Moreira',
#        'Vinicius Moura', 'Pedro Lucas Lima', 'Samuel Melo',
#        'Augusto Duarte', 'Otávio Ferreira', 'Stella da Rocha',
#        'Letícia Sales', 'João Gabriel Castro', 'Fernanda Cardoso',
#        'Otávio Caldeira', 'Enzo Gabriel Carvalho', 'Ana Lívia Porto',
#        'Gabriela Duarte', 'Júlia Jesus', 'Mirella das Neves',
#        'Gustavo Henrique Porto', 'Vitor Teixeira', 'Pedro Henrique Sales',
#        'Mariane Moura', 'Caio Porto', 'Melissa da Costa',
#        'Emanuelly da Luz', 'Isabel Carvalho', 'Gabriela Pinto',
#        'Davi Lucas da Costa', 'Caio Cavalcanti', 'Larissa Nascimento',
#        'Yago Teixeira', 'Isabella Viana', 'Nina Aragão',
#        'Maria Julia Farias', 'Marcos Vinicius Costa', 'Sophia da Mata',
#        'Juan Jesus', 'Lucas Gonçalves', 'Vicente Aragão',
#        'Luiz Otávio Viana', 'Isadora Gonçalves', 'Evelyn Lima',
#        'Bruno Rocha', 'Vitor Hugo Souza', 'Stella Pinto', 'Igor Carvalho',
#        'Pedro Miguel Rocha', 'Thomas Alves', 'Joaquim Pinto',
#        'Agatha Carvalho', 'Luigi Carvalho', 'Maria Alice Caldeira',
#        'Yuri Viana', 'Leandro Moreira', 'Ana Júlia Moura',
#        'Murilo Rodrigues', 'Isadora Oliveira', 'Gabriela Fernandes',
#        'Pedro Freitas', 'Stella Moreira', 'Raquel Gonçalves',
#        'Vitória Souza'], dtype=object)

# %% [markdown]
# - **En la 4° posicion se puede ver un cliente que se llama prueba, lo filtrare y lo eliminare**

# %%
df_ventas_limpio['ciudad'].unique()
# Out:
# array(['Ribeirão Preto', 'Rio de Janeiro', 'Foz do Iguaçu',
#        'São João de Meriti', 'Fortaleza', 'Rio Branco',
#        'Itapecerica da Serra', 'Salvador', 'Porto Seguro', 'Brasília',
#        'Teixeira de Freitas', 'Belo Horizonte', 'Botucatu',
#        'Balneário Camboriú', 'Itapevi', 'São José dos Pinhais',
#        'São Paulo', 'Maringá', 'Manaus', 'Imperatriz', 'Goiânia',
#        'São Gonçalo', 'Mogi das Cruzes', 'Florianópolis', 'Timon',
#        'Maceió', 'São José dos Campos', 'Petrolina', 'Itaquaquecetuba',
#        'Duque de Caxias', 'Santo André', 'Curitiba', 'Americana',
#        'Macapá', 'Parnamirim', 'Campo Grande', 'Piracicaba', 'Joinville',
#        'Campinas', 'Serra', 'Maracanaú', 'Aparecida de Goiânia',
#        'Rio Claro', 'São Bernardo do Campo', 'Vitória da Conquista',
#        'Osasco', 'Sete Lagoas', 'Barueri', 'Ji-Paraná',
#        'Ribeirão das Neves', 'Contagem', 'Belém', 'Ribeirão Pires',
#        'Itapetininga', 'São José', 'Guarulhos', 'Catanduva',
#        'Volta Redonda', 'Recife', 'Embu das Artes', 'Sabará',
#        'Petrópolis', 'Governador Valadares', 'Olinda',
#        'São José de Ribamar', 'Jaboatão dos Guararapes', 'Teresina',
#        'Colatina', 'Magé', 'Natal', 'Águas Lindas de Goiás', 'Ananindeua',
#        'Juazeiro do Norte', 'Itajaí', 'Campos dos Goytacazes',
#        'Praia Grande', 'São Carlos', 'Taubaté', 'Caruaru', 'João Pessoa',
#        'Votorantim', 'São Luís', 'Nova Iguaçu', 'Aracaju',
#        'Bragança Paulista', 'Vitória', 'Linhares', 'Niterói', 'Londrina',
#        'Paranaguá', 'Porto Velho', 'Camaragibe', 'Guarapuava', 'Diadema',
#        'Jundiaí', 'Juiz de Fora', 'Araraquara', 'Três Lagoas',
#        'Divinópolis', 'Cuiabá', 'Anápolis', 'Ibirité', 'Várzea Grande',
#        'Maranguape', 'Parnaíba', 'Limeira', 'São José do Rio Preto',
#        'Marília', 'Barcarena', 'Uberlândia', 'Campo Largo', 'Santos',
#        'Colombo', 'Sorocaba', 'Uberaba', 'Abaetetuba', 'Franco da Rocha',
#        'Sumaré', 'Belford Roxo', 'Cotia', 'São Félix do Xingu', 'Marabá',
#        'Castanhal', 'Luziânia', 'Resende', 'Macaé', 'Campina Grande',
#        'Boa Vista', 'Santarém', 'Cachoeiro de Itapemirim',
#        'Nossa Senhora do Socorro', 'Araucária', 'São Mateus',
#        'Patos de Minas', 'Teresópolis', 'Lauro de Freitas',
#        'Montes Claros', 'Itu', 'Paço do Lumiar', 'Vila Velha',
#        'Rio das Ostras', 'Caxias', 'Araçatuba', 'Araguaína', 'Araruama',
#        'São Vicente', 'Ferraz de Vasconcelos', 'Criciúma', 'Atibaia',
#        'Sinop', 'Ponta Grossa', 'Mossoró', 'Toledo', 'Taboão da Serra',
#        'Brusque', 'Hortolândia', 'Franca', 'Barra Mansa', 'Caraguatatuba',
#        'Palmas', 'Indaiatuba', 'Jacareí', 'Mauá', 'Santana de Parnaíba',
#        'Itabuna', 'Ipatinga', "Santa Bárbara d'Oeste", 'Caucaia',
#        'Rondonópolis', 'Feira de Santana', 'Mesquita', 'Carapicuíba',
#        'Sobral', 'Parauapebas', 'Trindade', 'Cametá', 'Teófilo Otoni',
#        'Paulista', 'Blumenau', 'Camaçari', 'Bragança', 'Arapiraca',
#        'São Caetano do Sur', 'Guarapari', 'Queimados', 'Sertãozinho',
#        'Birigui', 'Jaú', 'Cariacica', 'Bauru', 'Cascavel',
#        'Vitória de Santo Antão', 'Presidente Prudente', 'Poços de Caldas',
#        'Varginha', 'Itaboraí', 'Valinhos', 'Cabo Frio', 'Suzano', 'Betim',
#        'Santa Rita', 'Pouso Alegre', 'Barreiras', 'Juazeiro',
#        'Vespasiano', 'Itaguaí', 'Cabo de Santo Agostinho', 'Maricá',
#        'Santana', 'Jaraguá do Sur', 'Barretos', 'Crato', 'Codó',
#        'Simões Filho', 'Angra dos Reis', 'Nova Friburgo', 'Nilópolis',
#        'Alagoinhas', 'Chapecó', 'Apucarana', 'Guarujá', 'Jandira',
#        'Marituba', 'Rio Verde', 'Dourados', 'Itapipoca',
#        'Pindamonhangaba', 'Araras', 'Jequié', 'Itabira', 'Pinhais',
#        'Formosa', 'Francisco Morato', 'Ilhéus', 'Barbacena', 'Itatiba',
#        'Lages', 'Garanhuns', 'Várzea Paulista', 'Tatuí', 'Santa Luzia',
#        'Mogi Guaçu', 'Guaratinguetá', 'Arapongas', 'Cubatão',
#        'Valparaíso de Goiás', 'Palhoça', 'Conselheiro Lafaiete'],
#       dtype=object)

# %% [markdown]
# ### 2.4 Eliminar filas con registros de prueba

# %%
# Filtramos la columna nombre_cliente cuyo valor sea prueba
df_ventas_prueba = df_ventas_limpio[df_ventas_limpio['nombre_cliente'] == 'prueba']
df_ventas_prueba
# Out:
#      fecha_pedido fecha_envio        modo_envio nombre_cliente  \
# 12     2022-04-16  2022-04-21  Entrega estándar         prueba
# 2634   2022-11-19  2022-11-25  Entrega estándar         prueba
# 4001   2022-08-15  2022-08-22  Entrega estándar         prueba
# 4037   2021-11-15  2021-11-19  Entrega estándar         prueba
#
#      segmento_cliente              ciudad          estado   region  \
# 12                B2C  São João de Meriti  Rio de Janeiro  Sureste
# 2634              B2B      Ribeirão Pires       São Paulo  Sureste
# 4001              B2C      Rio de Janeiro  Rio de Janeiro  Sureste
# 4037              B2C      Belo Horizonte    Minas Gerais  Sureste
#
#       departamento_producto     tipo_producto  precio_base  \
# 12    Productos de Limpieza  Bolsas de basura        14.54
# 2634                   Ropa          Vestidos        13.27
# 4001                   Ropa        Zapatillas       471.11
# 4037           Electrónicos      Lámparas LED         7.22
#
#       precio_unit_sin_desc  descuento  precio_unit_venta  cantidad_pedido  \
# 12                   19.59        0.1              17.63                3
# 2634                 16.80        0.0              16.80                4
# 4001                526.74        0.1             474.07                3
# 4037                  6.50        0.4               3.90                2
#
#       total_venta  total_ganancia
# 12          52.89            9.27
# 2634        67.20           14.12
# 4001      1422.21            8.88
# 4037         7.80           -6.64

# %%
# Eliminamos de la columna nombre_cliente las filas cuyo valor sea prueba
df_ventas_limpio = df_ventas_limpio[df_ventas_limpio['nombre_cliente'] != 'prueba']

# %%
# comprobamos que no tengamos duplicados
df_ventas_limpio[df_ventas_limpio['nombre_cliente'] == 'prueba']
# Out:
# Empty DataFrame
# Columns: [fecha_pedido, fecha_envio, modo_envio, nombre_cliente, segmento_cliente, ciudad, estado, region, departamento_producto, tipo_producto, precio_base, precio_unit_sin_desc, descuento, precio_unit_venta, cantidad_pedido, total_venta, total_ganancia]
# Index: []

# %% [markdown]
# ### 2.5 Eliminar filas con valor nulo

# %%
# Ver cantidad de datos nulos por columna
df_ventas_limpio.isnull().sum()
# Out:
# fecha_pedido             0
# fecha_envio              0
# modo_envio               0
# nombre_cliente           2
# segmento_cliente         0
# ciudad                   0
# estado                   0
# region                   0
# departamento_producto    0
# tipo_producto            0
# precio_base              0
# precio_unit_sin_desc     0
# descuento                0
# precio_unit_venta        0
# cantidad_pedido          0
# total_venta              0
# total_ganancia           0
# dtype: int64

# %% [markdown]
# **Eliminar filas con valor nulo en la columna nombre_cliente**

# %%
# Eliminamos los dos datos nulos en la columna nombre_cliente
df_ventas_limpio = df_ventas_limpio.dropna(subset=['nombre_cliente'])
df_ventas_limpio.isnull().sum()
# Out:
# fecha_pedido             0
# fecha_envio              0
# modo_envio               0
# nombre_cliente           0
# segmento_cliente         0
# ciudad                   0
# estado                   0
# region                   0
# departamento_producto    0
# tipo_producto            0
# precio_base              0
# precio_unit_sin_desc     0
# descuento                0
# precio_unit_venta        0
# cantidad_pedido          0
# total_venta              0
# total_ganancia           0
# dtype: int64

# %% [markdown]
# ### 2.6 Filtrar operaciones sin ganancia

# %%
df_ventas_limpio.describe()
# Out:
#                         fecha_pedido                    fecha_envio  \
# count                           8933                           8933
# mean   2021-05-01 22:51:00.382850304  2021-04-30 21:21:13.077353472
# min              2019-01-04 00:00:00            2019-01-08 00:00:00
# 25%              2020-05-26 00:00:00            2020-05-16 00:00:00
# 50%              2021-06-27 00:00:00            2021-06-25 00:00:00
# 75%              2022-05-16 00:00:00            2022-05-16 00:00:00
# max              2022-12-31 00:00:00            2022-12-31 00:00:00
# std                              NaN                            NaN
#
#        precio_base  precio_unit_sin_desc    descuento  precio_unit_venta  \
# count  8933.000000           8933.000000  8933.000000        8933.000000
# mean    196.174135            227.386990     0.077201         209.925325
# min       2.060000              1.900000     0.000000           1.140000
# 25%      15.990000             20.030000     0.000000          18.670000
# 50%      50.580000             60.380000     0.075000          55.350000
# 75%     208.220000            237.860000     0.100000         217.570000
# max    9043.980000          11899.970000     0.400000       11899.970000
# std     436.385758            522.231704     0.103031         486.365531
#
#        cantidad_pedido   total_venta  total_ganancia
# count      8933.000000   8933.000000     8933.000000
# mean          3.803649    792.389409       50.850146
# min           1.000000      1.510000   -11219.950000
# 25%           2.000000     59.350000        3.000000
# 50%           3.000000    187.040000       14.800000
# 75%           5.000000    717.960000       50.450000
# max          14.000000  59499.850000    14280.000000
# std           2.235908   2049.241482      415.595741

# %% [markdown]
# **se ven numero negativos en total_ganancia**

# %%
# Filtro las "perdidas" los valores menor a cero 
filtro_perdidas = df_ventas_limpio[df_ventas_limpio['total_ganancia'] < 0]
filtro_perdidas
# Out:
#      fecha_pedido fecha_envio        modo_envio                nombre_cliente  \
# 3      2020-10-12  2020-10-19  Entrega estándar             Ana Júlia da Cruz
# 14     2020-11-23  2020-11-27  Entrega estándar               Nicolas Rezende
# 15     2020-11-23  2020-11-27  Entrega estándar               Nicolas Rezende
# 22     2022-07-17  2022-07-19         Económico                 Bianca Campos
# 26     2020-09-18  2020-09-22  Entrega estándar              Felipe Rodrigues
# ...           ...         ...               ...                           ...
# 8871   2021-03-16  2021-03-20  Entrega estándar                Ana Lívia Dias
# 8872   2019-11-25  2019-12-01  Entrega estándar        João Gabriel das Neves
# 8882   2020-11-14  2020-11-18  Entrega estándar                Danilo Barbosa
# 8886   2021-06-04  2021-06-07         Económico             Henrique Carvalho
# 8911   2020-03-20  2020-03-23      Envío rápido  Marcos Vinicius da Conceição
#
#      segmento_cliente                ciudad            estado        region  \
# 3                 B2C         Foz do Iguaçu            Paraná           Sur
# 14                B2B            Rio Branco              Acre         Norte
# 15                B2B            Rio Branco              Acre         Norte
# 22                B2C              Brasília  Distrito Federal  Centro-Oeste
# 26                B2C              Brasília  Distrito Federal  Centro-Oeste
# ...               ...                   ...               ...           ...
# 8871              B2B  Conselheiro Lafaiete      Minas Gerais       Sureste
# 8872              B2B    Ribeirão das Neves      Minas Gerais       Sureste
# 8882              B2C    São Caetano do Sur         São Paulo       Sureste
# 8886              B2B        Rio de Janeiro    Rio de Janeiro       Sureste
# 8911              B2B        Belo Horizonte      Minas Gerais       Sureste
#
#       departamento_producto         tipo_producto  precio_base  \
# 3                      Ropa            Zapatillas       781.38
# 14    Productos de Limpieza  Ambientador en spray        88.90
# 15             Electrónicos          Lámparas LED         5.04
# 22                     Ropa                 Jeans       122.20
# 26                     Ropa             Camisetas      1902.04
# ...                     ...                   ...          ...
# 8871           Electrónicos          Lámparas LED        19.57
# 8872           Electrónicos          Lámparas LED         9.11
# 8882                   Ropa             Camisetas       597.92
# 8886                   Ropa            Zapatillas       122.36
# 8911                   Ropa             Camisetas       354.70
#
#       precio_unit_sin_desc  descuento  precio_unit_venta  cantidad_pedido  \
# 3                   840.19      0.225             651.15                5
# 14                   77.98      0.400              46.79                5
# 15                    4.80      0.400               2.88                3
# 22                  142.74      0.150             121.33                2
# 26                 1996.89      0.250            1497.67                7
# ...                    ...        ...                ...              ...
# 8871                 18.12      0.400              10.87                7
# 8872                 10.02      0.350               6.51                3
# 8882                627.92      0.075             580.83                4
# 8886                134.28      0.100             120.85                2
# 8911                388.02      0.160             325.94                4
#
#       total_venta  total_ganancia
# 3         3255.75         -651.15
# 14         233.95         -210.55
# 15           8.64           -6.48
# 22         242.66           -1.74
# 26       10483.69        -2830.59
# ...           ...             ...
# 8871        76.09          -60.90
# 8872        19.53           -7.80
# 8882      2323.32          -68.36
# 8886       241.70           -3.02
# 8911      1303.76         -115.04
#
# [1663 rows x 17 columns]

# %% [markdown]
# ### filtramos las filas donde el valor en la columna total_ganancia es mayor que cero y eliminamos

# %%
# filtramos las filas donde el valor en la columna total_ganancia es mayor que cero
# reset_index para actualizar el índice del DataFrame. 
# el parámetro drop=True se utiliza para descartar el índice anterior
df_ventas_limpio = df_ventas_limpio[df_ventas_limpio['total_ganancia'] > 0]
df_ventas_limpio = df_ventas_limpio.reset_index(drop=True)

# %%
df_ventas_limpio.shape
# Out:
# (7210, 17)

# %% [markdown]
# ### DF limpio

# %%
print('Informacion:')
print(df_ventas_limpio.info())
print('------------')
print('Duplicados:')
print(df_ventas_limpio.duplicated().sum())
print('------------')
print('Registros de pruebas:')
print((df_ventas_limpio['nombre_cliente'] == 'prueba').sum())
print('------------')
print('Registros con ganancias <=0')
print((df_ventas_limpio['total_ganancia'] <=0).sum())
# Out:
# Informacion:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7210 entries, 0 to 7209
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_pedido           7210 non-null   datetime64[ns]
#  1   fecha_envio            7210 non-null   datetime64[ns]
#  2   modo_envio             7210 non-null   object
#  3   nombre_cliente         7210 non-null   object
#  4   segmento_cliente       7210 non-null   object
#  5   ciudad                 7210 non-null   object
#  6   estado                 7210 non-null   object
#  7   region                 7210 non-null   object
#  8   departamento_producto  7210 non-null   object
#  9   tipo_producto          7210 non-null   object
#  10  precio_base            7210 non-null   float64
#  11  precio_unit_sin_desc   7210 non-null   float64
#  12  descuento              7210 non-null   float64
#  13  precio_unit_venta      7210 non-null   float64
#  14  cantidad_pedido        7210 non-null   int64
#  15  total_venta            7210 non-null   float64
#  16  total_ganancia         7210 non-null   float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(8)
# memory usage: 957.7+ KB
# None
# ------------
# Duplicados:
# 0
# ------------
# Registros de pruebas:
# 0
# ------------
# Registros con ganancias <=0
# 0

# %% [markdown]
# ## Funcion para obtener y limpiar datos

# %%
def obtencion_datos():
    import pandas as pd 
    import matplotlib.pyplot as plt  
    import matplotlib.dates as mdates
    global df_ventas, df_ventas_limpio
    
    df_ventas = pd.read_csv("reporte_ventas.csv", sep=",")
    print('Informacion:')
    print(df_ventas.info())
    print('------------')
    print('Duplicados:')
    print(df_ventas.duplicated().sum())
    print('------------')
    print('Registros de pruebas:')
    print((df_ventas['nombre_cliente'] == 'prueba').sum())
    print('------------')
    print('Registros con ganancias <=0')
    print((df_ventas['total_ganancia'] <=0).sum())
    
    df_ventas['fecha_pedido'] = pd.to_datetime(df_ventas['fecha_pedido'], format='%Y-%m-%d')
    df_ventas['fecha_envio'] = pd.to_datetime(df_ventas['fecha_envio'], format='%Y-%m-%d')
    
    print(f'Tamaño del set antes de eliminar las filas repetidas: {df_ventas.shape}')
    df_ventas_limpio = df_ventas.drop_duplicates(inplace=False)  # inplace=False para que devuelva un nuevo DataFrame
    print(f'Tamaño del set después de eliminar las filas repetidas: {df_ventas_limpio.shape}')
    
    # Eliminamos de la columna nombre_cliente las filas cuyo valor sea prueba
    df_ventas_limpio = df_ventas_limpio[df_ventas_limpio['nombre_cliente'] != 'prueba']
    
    # Eliminamos los dos datos nulos en la columna nombre_cliente
    df_ventas_limpio = df_ventas_limpio.dropna(subset=['nombre_cliente'])
    
    # filtramos las filas donde el valor en la columna total_ganancia es mayor que cero
    # reset_index para actualizar el índice del DataFrame. 
    # ll parámetro drop=True se utiliza para descartar el índice anterior
    df_ventas_limpio = df_ventas_limpio[df_ventas_limpio['total_ganancia'] > 0]
    df_ventas_limpio = df_ventas_limpio.reset_index(drop=True)
    
    # Df limpio
    print('Informacion:')
    print(df_ventas_limpio.info())
    print('------------')
    print('Duplicados:')
    print(df_ventas_limpio.duplicated().sum())
    print('------------')
    print('Registros de pruebas:')
    print((df_ventas_limpio['nombre_cliente'] == 'prueba').sum())
    print('------------')
    print('Registros con ganancias <=0')
    print((df_ventas_limpio['total_ganancia'] <=0).sum())
    
obtencion_datos()
# Out:
# Informacion:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8954 entries, 0 to 8953
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_pedido           8954 non-null   object
#  1   fecha_envio            8954 non-null   object
#  2   modo_envio             8954 non-null   object
#  3   nombre_cliente         8952 non-null   object
#  4   segmento_cliente       8954 non-null   object
#  5   ciudad                 8954 non-null   object
#  6   estado                 8954 non-null   object
#  7   region                 8954 non-null   object
#  8   departamento_producto  8954 non-null   object
#  9   tipo_producto          8954 non-null   object
#  10  precio_base            8954 non-null   float64
#  11  precio_unit_sin_desc   8954 non-null   float64
#  12  descuento              8954 non-null   float64
#  13  precio_unit_venta      8954 non-null   float64
#  14  cantidad_pedido        8954 non-null   int64
#  15  total_venta            8954 non-null   float64
#  16  total_ganancia         8954 non-null   float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 1.2+ MB
# None
# ------------
# Duplicados:
# 15
# ------------
# Registros de pruebas:
# 4
# ------------
# Registros con ganancias <=0
# 1726
# Tamaño del set antes de eliminar las filas repetidas: (8954, 17)
# Tamaño del set después de eliminar las filas repetidas: (8939, 17)
# Informacion:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7210 entries, 0 to 7209
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fecha_pedido           7210 non-null   datetime64[ns]
#  1   fecha_envio            7210 non-null   datetime64[ns]
#  2   modo_envio             7210 non-null   object
#  3   nombre_cliente         7210 non-null   object
#  4   segmento_cliente       7210 non-null   object
#  5   ciudad                 7210 non-null   object
#  6   estado                 7210 non-null   object
#  7   region                 7210 non-null   object
#  8   departamento_producto  7210 non-null   object
#  9   tipo_producto          7210 non-null   object
#  10  precio_base            7210 non-null   float64
#  11  precio_unit_sin_desc   7210 non-null   float64
#  12  descuento              7210 non-null   float64
#  13  precio_unit_venta      7210 non-null   float64
#  14  cantidad_pedido        7210 non-null   int64
#  15  total_venta            7210 non-null   float64
#  16  total_ganancia         7210 non-null   float64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(8)
# memory usage: 957.7+ KB
# None
# ------------
# Duplicados:
# 0
# ------------
# Registros de pruebas:
# 0
# ------------
# Registros con ganancias <=0
# 0

# %% [markdown]
# -----------------

# %% [markdown]
# ## 3. **Pregunta 1: ¿Cuáles son las ventas totales por año? ¿Y qué año tuvo mejor desempeño?**

# %% [markdown]
# ### 1.1 Crea una copia de la base df_ventas_limpio en un nuevo dataframe df_ventas_año

# %%
# Creamos un nuevo df con las columnas de fecha y total ventas
df_ventas_año = df_ventas_limpio[['fecha_pedido', 'total_venta']].copy()
df_ventas_año
# Out:
#      fecha_pedido  total_venta
# 0      2021-11-09       890.66
# 1      2021-11-09      2488.59
# 2      2021-06-13        49.72
# 3      2020-10-12        76.04
# 4      2019-06-10       166.11
# ...           ...          ...
# 7205   2021-09-30       123.22
# 7206   2022-11-18       271.97
# 7207   2022-11-18       700.75
# 7208   2019-01-22        85.83
# 7209   2022-05-05       826.74
#
# [7210 rows x 2 columns]

# %% [markdown]
# ### 1.2 Creamos una nueva columna en df_ventas_año llamada año y  eliminamos la columna fecha_pedido

# %%
# Creamos una nueva columna año a partir de la columna fecha_pedido
df_ventas_año['año'] = df_ventas_año['fecha_pedido'].dt.year
df_ventas_año
# Out:
#      fecha_pedido  total_venta   año
# 0      2021-11-09       890.66  2021
# 1      2021-11-09      2488.59  2021
# 2      2021-06-13        49.72  2021
# 3      2020-10-12        76.04  2020
# 4      2019-06-10       166.11  2019
# ...           ...          ...   ...
# 7205   2021-09-30       123.22  2021
# 7206   2022-11-18       271.97  2022
# 7207   2022-11-18       700.75  2022
# 7208   2019-01-22        85.83  2019
# 7209   2022-05-05       826.74  2022
#
# [7210 rows x 3 columns]

# %%
# Eliminamos la columna fecha_pedido
df_ventas_año.drop(['fecha_pedido'], axis=1, inplace=True)
df_ventas_año
# Out:
#       total_venta   año
# 0          890.66  2021
# 1         2488.59  2021
# 2           49.72  2021
# 3           76.04  2020
# 4          166.11  2019
# ...           ...   ...
# 7205       123.22  2021
# 7206       271.97  2022
# 7207       700.75  2022
# 7208        85.83  2019
# 7209       826.74  2022
#
# [7210 rows x 2 columns]

# %% [markdown]
# ### 1.3 agrupamos por la columna año y sumamos los valores

# %%
# agrupamos por la columna año y sumamos los valores
df_ventas_año = df_ventas_año.groupby('año').aggregate({'total_venta': 'sum'}).reset_index()
df_ventas_año
# Out:
#     año  total_venta
# 0  2019   1052735.86
# 1  2020   1190541.40
# 2  2021   1535801.44
# 3  2022   1825927.50

# %% [markdown]
# ###  Calculamos el porcentaje de aumento de las ventas en cada año

# %%
# Calculamos el porcentaje de aumento de las ventas en cada año
df_ventas_año_aumento = df_ventas_año.copy()
df_ventas_año_aumento['porcentaje_aumento'] = df_ventas_año_aumento['total_venta'].pct_change() * 100

# Filtrar para excluir el primer año ya que no hay un año anterior para calcular el cambio porcentual
df_ventas_año_aumento = df_ventas_año_aumento[df_ventas_año_aumento['año'] != df_ventas_año_aumento['año'].min()]

print("Porcentaje de Aumento de Ventas:")
print("")
#print(df_ventas_año_aumento[['año', 'porcentaje_aumento']])
df_ventas_año_aumento
# Out:
# Porcentaje de Aumento de Ventas:
#     año  total_venta  porcentaje_aumento
# 1  2020   1190541.40           13.090229
# 2  2021   1535801.44           29.000255
# 3  2022   1825927.50           18.890857

# %% [markdown]
# ### **Funcion para responder Cuáles son las ventas totales por año Y qué año tuvo mejor desempeño**

# %%
def  pregunta_1():
    global df_ventas, df_ventas_limpio
    
    # Creamos un nuevo df con las columnas de fecha
    df_ventas_año = df_ventas_limpio[['fecha_pedido', 'total_venta']].copy()
    # Creamos una nueva columna año
    df_ventas_año['año'] = df_ventas_año['fecha_pedido'].dt.year
    # Eliminamos la columna fecha_pedido
    df_ventas_año.drop(['fecha_pedido'], axis=1, inplace=True)
    # agrupamos por la columna año y sumamos los valores
    df_ventas_año = df_ventas_año.groupby('año').aggregate({'total_venta': 'sum'}).reset_index()
    # graficamos
    # Creamos una lista de colores
    colores = ['#CDDBF3', '#CDDBF3', '#CDDBF3', '#0077b6']

    # Crear la figura y el eje
    fig, ax = plt.subplots(figsize=(10, 4))

    # Crear el gráfico de barras verticales
    ax.bar(df_ventas_año['año'], df_ventas_año['total_venta'], color=colores, width=0.8)

    # Colocar los valores sobre cada barra
    for bar in ax.patches:
        valor = bar.get_height()
        qtd = f"USD${valor:,.2f}"  # Formatear el valor como texto con símbolo de dólar
        ax.text(bar.get_x() + bar.get_width() / 2.0, valor, qtd, ha='center', va='bottom',fontsize=11,  color='black')

    # Configuramos el titulo
    ax.set_title('Ventas Totales por Año\n(2019-2022)',loc='left', fontsize=15,  color='black')

    # Controlar el formato de las etiquetas del eje X
    ax.set_xticks(df_ventas_año['año'])
    ax.set_xticklabels(df_ventas_año['año'].astype(int))

    # Ocultar todos los bordes del gráfico
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Quitar los ticks del eje X y Y
    ax.tick_params(axis='both', which='both', length=0)
    ax.set_yticks([])  # Ocultar los ticks del eje Y

    # Texto 
    texto = ("En $\\mathbf{2022}$, las ventas\n"
             "en el supermercado subieron\n"
             "aproximadamente $\\mathbf{18.89\\%}$\n"
             "comparado con el año anterior.")

    # egundo texto
    texto2 = ("año            aumento\n"
              "2020           13.09%\n"
              "2021           29.00%\n"
              "2022           18.89%")

    # Añadir texto y alinear 
    ax.text(1.10, 0.70, texto, transform=ax.transAxes, ha='left', va='bottom', fontsize=14, color='blue')
    ax.text(1.10, 0.0, texto2, transform=ax.transAxes, ha='left', va='bottom', fontsize=14, color='blue')

    plt.show()

pregunta_1()

# %% [markdown]
# ## 4. Pregunta2

# %% [markdown]
#  ## Pregunta 2: ¿Cuáles son los 7 productos que más ganancias mostraron durante todo el período?

# %%
df_ventas_limpio
# Out:
#      fecha_pedido fecha_envio        modo_envio     nombre_cliente  \
# 0      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 1      2021-11-09  2021-11-12         Económico    Thiago Silveira
# 2      2021-06-13  2021-06-17         Económico      Giovanna Lima
# 3      2020-10-12  2020-10-19  Entrega estándar  Ana Júlia da Cruz
# 4      2019-06-10  2019-06-15  Entrega estándar        Sophia Dias
# ...           ...         ...               ...                ...
# 7205   2021-09-30  2021-10-04  Entrega estándar     Enrique Santos
# 7206   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 7207   2022-11-18  2022-11-22  Entrega estándar    Heitor Silveira
# 7208   2019-01-22  2019-01-24         Económico      Isabel Araújo
# 7209   2022-05-05  2022-05-10         Económico   Esther Rodrigues
#
#      segmento_cliente          ciudad               estado   region  \
# 0                 B2C  Ribeirão Preto            São Paulo  Sureste
# 1                 B2C  Ribeirão Preto            São Paulo  Sureste
# 2                 B2B  Rio de Janeiro       Rio de Janeiro  Sureste
# 3                 B2C   Foz do Iguaçu               Paraná      Sur
# 4                 B2C  Rio de Janeiro       Rio de Janeiro  Sureste
# ...               ...             ...                  ...      ...
# 7205              B2C  Rio de Janeiro       Rio de Janeiro  Sureste
# 7206              B2B          Jequié                Bahia  Noreste
# 7207              B2B          Jequié                Bahia  Noreste
# 7208              B2C     João Pessoa              Paraíba  Noreste
# 7209              B2C         Mossoró  Rio Grande do Norte  Noreste
#
#       departamento_producto             tipo_producto  precio_base  \
# 0                      Ropa                 Camisetas       409.70
# 1                      Ropa                     Jeans       705.10
# 2     Productos de Limpieza  Toallitas desinfectantes        19.02
# 3     Productos de Limpieza           Papel higiénico        35.88
# 4                      Ropa                  Vestidos        20.29
# ...                     ...                       ...          ...
# 7205           Electrónicos               Smartphones        97.34
# 7206           Electrónicos               Smartphones       223.01
# 7207           Electrónicos         Cámaras digitales       121.23
# 7208                   Ropa                  Vestidos        26.29
# 7209  Productos de Limpieza      Ambientador en spray       351.36
#
#       precio_unit_sin_desc  descuento  precio_unit_venta  cantidad_pedido  \
# 0                   445.33        0.0             445.33                2
# 1                   829.53        0.0             829.53                3
# 2                    24.86        0.0              24.86                2
# 3                    42.24        0.1              38.02                2
# 4                    23.73        0.0              23.73                7
# ...                    ...        ...                ...              ...
# 7205                123.22        0.0             123.22                1
# 7206                271.97        0.0             271.97                1
# 7207                140.15        0.0             140.15                5
# 7208                 31.79        0.1              28.61                3
# 7209                413.37        0.0             413.37                2
#
#       total_venta  total_ganancia
# 0          890.66           71.26
# 1         2488.59          373.29
# 2           49.72           11.68
# 3           76.04            4.28
# 4          166.11           24.08
# ...           ...             ...
# 7205       123.22           25.88
# 7206       271.97           48.96
# 7207       700.75           94.60
# 7208        85.83            6.96
# 7209       826.74          124.02
#
# [7210 rows x 17 columns]

# %% [markdown]
# ### 4.1 Creamos un nuevo df con las columnas tipo_producto y total_ganancia a partir de el df_ventas_limpio

# %%
# Crea una copia del DataFrame df_ventas_limpio
df_top_ganancias = df_ventas_limpio.copy()

# Crear un DataFrame nuevo con los datos de las columnas tipo_producto y total_ganancia
df_top_ganancias = df_top_ganancias[['tipo_producto', 'total_ganancia']]
df_top_ganancias.head()
# Out:
#               tipo_producto  total_ganancia
# 0                 Camisetas           71.26
# 1                     Jeans          373.29
# 2  Toallitas desinfectantes           11.68
# 3           Papel higiénico            4.28
# 4                  Vestidos           24.08

# %% [markdown]
# ### 4.2 Agrupamos por tipo_producto, sumar la columna total_ganancia y ordenar en orden descendente

# %%
# agrupamos por tipo_producto y departamento_producto luego sumamos los valores de la columna total_ganancia
df_top_ganancias = df_top_ganancias.groupby('tipo_producto')['total_ganancia'].agg('sum')

# ordenamos  la columna total_ganancia en orden descendente 
df_top_ganancias = df_top_ganancias.sort_values(ascending=False)

# recetear el index
df_top_ganancias = df_top_ganancias.reset_index(name='total_ganancia')
df_top_ganancias
# Out:
#                tipo_producto  total_ganancia
# 0               Lámparas LED       111453.41
# 1                    Laptops        91148.67
# 2          Cámaras digitales        80192.63
# 3                Smartphones        64705.58
# 4                      Jeans        55982.95
# 5      Detergente para ropas        55766.39
# 6           Bolsas de basura        53328.46
# 7            Papel higiénico        43546.05
# 8       Ambientador en spray        40976.16
# 9                   Vestidos        29784.63
# 10                Zapatillas        21546.88
# 11                 Camisetas        14182.38
# 12           Limpiacristales        11254.88
# 13     Limpiador de inodoros         9939.43
# 14  Toallitas desinfectantes         8865.09
# 15    Detergente para platos         2859.87
# 16          Cepillos de baño         1436.84

# %% [markdown]
# ### 4.3 Los 7 productos con mas ganancias

# %%
# ordenamos el DataFrame por total_ganancia en orden descendente
df_top_ganancias = df_top_ganancias.sort_values(by='total_ganancia', ascending=False)

# Resetear los indices para mantener el orden original
df_top_ganancias = df_top_ganancias.reset_index(drop=True)

# Seleccionar los primeros 7 registros
df_top_ganancias = df_top_ganancias.head(7)

df_top_ganancias
# Out:
#            tipo_producto  total_ganancia
# 0           Lámparas LED       111453.41
# 1                Laptops        91148.67
# 2      Cámaras digitales        80192.63
# 3            Smartphones        64705.58
# 4                  Jeans        55982.95
# 5  Detergente para ropas        55766.39
# 6       Bolsas de basura        53328.46

# %% [markdown]
# ---------------------------------------------------------------------------

# %% [markdown]
# ###  Visualización

# %%
def pregunta_2():
    global df_ventas, df_ventas_limpio
    
    # Crea una copia del DataFrame df_ventas_limpio
    df_top_ganancias = df_ventas_limpio.copy()

    # Crear un DataFrame nuevo con los datos de las columnas tipo_producto y total_ganancia
    df_top_ganancias = df_top_ganancias[['tipo_producto', 'total_ganancia']]
    
    # agrupamos por tipo_producto y departamento_producto luego sumamos los valores de la columna total_ganancia
    df_top_ganancias = df_top_ganancias.groupby('tipo_producto')['total_ganancia'].agg('sum')

    # ordenamos  la columna total_ganancia en orden descendente 
    df_top_ganancias = df_top_ganancias.sort_values(ascending=False)

    # recetear el index
    df_top_ganancias = df_top_ganancias.reset_index(name='total_ganancia')
    
    
    # ordenamos el DataFrame por total_ganancia en orden descendente
    df_top_ganancias = df_top_ganancias.sort_values(by='total_ganancia', ascending=False)

    # Resetear los indices para mantener el orden original
    df_top_ganancias = df_top_ganancias.reset_index(drop=True)

    # Seleccionar los primeros 7 registros
    df_top_ganancias = df_top_ganancias.head(7)

    

    # Creamos una lista de colores
    colores = ['#0077b6', '#0077b6', '#0077b6', '#0077b6', '#adb5bd', '#0C8040', '#0C8040']

    # Crear la figura y el eje
    fig, ax = plt.subplots(figsize=(10, 4))

    # Crear el gráfico de barras horizontales
    bars = ax.barh(df_top_ganancias['tipo_producto'], df_top_ganancias['total_ganancia'], color=colores, align='center')

    # Colocar los valores dentro de las barras con color blanco
    for bar in bars:
        valor = bar.get_width()
        qtd = f"USD${valor:,.2f}"  # Formatear el valor como texto con símbolo de dólar
        ax.text(valor, bar.get_y() + bar.get_height()/2, qtd, ha='right', va='center', color='white')

    # Configuración del titulo
    ax.set_title('Top 7 Productos con Mayor Ganancias (2019-2022)', loc='left', fontsize=15,  color='black')
    
    # Invertir el orden de las barras
    ax.invert_yaxis()

    # Ocultar todos los bordes del gráfico
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Quitar los ticks del eje X y Y
    ax.tick_params(axis='both', which='both', length=0)

    # Ocultar los ticks del eje Y
    ax.tick_params(axis='y', which='both', left=False)

    # Quitar los valores del eje X
    ax.set_xticks([])
    
    # Texto $\\mathbf{2022}$
    texto = ("Los 4 productos que generan\n"
         "$\\mathbf{mayor}$ $\\mathbf{ganancia}$ son los departamentos "
         "Electrónicos\n"  
         "\n"
         "Podemos notar también que el departamento de\n"
         "Producto de Limpieza tiene dos productos con\n" 
         "buena margen de ganancia, totalizando $\\mathbf{109\\ mil}$\n"  
         "durante el periodo analizado"
            )


    # Añadir texto y alinear 
    ax.text(1.0, 0.45, texto, transform=ax.transAxes, ha='left', va='bottom', fontsize=14, color='black')



    # Mostrar el gráfico
    plt.show()

 
pregunta_2()

# %% [markdown]
# ## 5. Pregunta 3: Si separamos las ventas totales por año y por regiones ¿Qué insight podemos obtener de nuestras ventas?

# %% [markdown]
# ### 5.1 Creamos un df a partir de df_ventas_limpio con la informacion de las columnas fecha_pedido, region, total_venta

# %%
# Creamos un df a partir de df_ventas_limpio con la informacion de las columnas fecha_pedido, region, total_venta 
df_ventas_año_region = df_ventas_limpio[['fecha_pedido', 'region', 'total_venta']].copy()
df_ventas_año_region
# Out:
#      fecha_pedido   region  total_venta
# 0      2021-11-09  Sureste       890.66
# 1      2021-11-09  Sureste      2488.59
# 2      2021-06-13  Sureste        49.72
# 3      2020-10-12      Sur        76.04
# 4      2019-06-10  Sureste       166.11
# ...           ...      ...          ...
# 7205   2021-09-30  Sureste       123.22
# 7206   2022-11-18  Noreste       271.97
# 7207   2022-11-18  Noreste       700.75
# 7208   2019-01-22  Noreste        85.83
# 7209   2022-05-05  Noreste       826.74
#
# [7210 rows x 3 columns]

# %% [markdown]
# ### 5.2 Creamos la columna año y eliminamos la columna fecha_pedido

# %%
# Creamos la columna año
df_ventas_año_region['año'] = df_ventas_año_region['fecha_pedido'].dt.year

# Eliminamos la columna fecha_pedido
df_ventas_año_region.drop(columns=['fecha_pedido'], inplace=True)
df_ventas_año_region
# Out:
#        region  total_venta   año
# 0     Sureste       890.66  2021
# 1     Sureste      2488.59  2021
# 2     Sureste        49.72  2021
# 3         Sur        76.04  2020
# 4     Sureste       166.11  2019
# ...       ...          ...   ...
# 7205  Sureste       123.22  2021
# 7206  Noreste       271.97  2022
# 7207  Noreste       700.75  2022
# 7208  Noreste        85.83  2019
# 7209  Noreste       826.74  2022
#
# [7210 rows x 3 columns]

# %% [markdown]
# ### 5.3  Generamos la tabla cruzada con el método pd.crosstab

# %%
# Generamos la tabla cruzada
df_ventas_año_region = pd.crosstab(index=df_ventas_año_region['año'], columns=df_ventas_año_region['region'], values=df_ventas_año_region['total_venta'], aggfunc='sum')

# Reordenamos las columnas
column_order = ['Sureste', 'Noreste', 'Centro-Oeste', 'Norte', 'Sur']
df_ventas_año_region = df_ventas_año_region[column_order]

df_ventas_año_region
# Out:
# region    Sureste    Noreste  Centro-Oeste      Norte        Sur
# año
# 2019    522953.51  346407.40      67406.37   71778.74   44189.84
# 2020    648732.79  282431.39      90616.80  107309.38   61451.04
# 2021    870894.51  359829.92     125344.52   69534.02  110198.47
# 2022    980404.44  549254.20      97679.64   99195.86   99393.36

# %% [markdown]
# ### 5.4 Visualizacion

# %%
# sumamos las ventas de las regiones Sureste, Noreste y Centro-Oeste para cada año
df_ventas_concentradas = df_ventas_año_region[['Sureste', 'Noreste', 'Centro-Oeste']].sum(axis=1)

# calculamos el porcentaje con respecto al total de ventas
total_ventas = df_ventas_año_region.sum(axis=1)
porcentaje_concentradas = (df_ventas_concentradas / total_ventas) * 100

print(f"Porcentaje de ventas concentradas en Sureste, Noreste y Centro-Oeste desde 2019: {porcentaje_concentradas.iloc[-1]:.2f}%")
# Out:
# Porcentaje de ventas concentradas en Sureste, Noreste y Centro-Oeste desde 2019: 89.12%

# %%
def pregunta_3():
    global df_ventas, df_ventas_limpio
    # Creamos un df a partir de df_ventas_limpio con la informacion de las columnas fecha_pedido, region, total_venta 
    df_ventas_año_region = df_ventas_limpio[['fecha_pedido', 'region', 'total_venta']].copy()
    # Creamos la columna año
    df_ventas_año_region['año'] = df_ventas_año_region['fecha_pedido'].dt.year
    # Eliminamos la columna fecha_pedido
    df_ventas_año_region.drop(columns=['fecha_pedido'], inplace=True)
    # Generamos la tabla cruzada
    df_ventas_año_region = pd.crosstab(index=df_ventas_año_region['año'], columns=df_ventas_año_region['region'], values=df_ventas_año_region['total_venta'], aggfunc='sum')

    # Reordenamos las columnas
    column_order = ['Sureste', 'Noreste', 'Centro-Oeste', 'Norte', 'Sur']
    df_ventas_año_region = df_ventas_año_region[column_order]
    # visuañizacion
    # Configuración de colores
    colores = ['#0077b6', '#00b4d8', '#90e0ef', '#adb5bd', '#dee2e6']

    # Crear el gráfico de columnas apiladas con bordes más visibles
    ax = df_ventas_año_region.plot(kind='bar', stacked=True, figsize=(15, 8), color=colores, edgecolor='white', linewidth=0.5)

    # Quitar la palabra "Año" en el eje x
    ax.set_xlabel("")

    # Quitar los ticks y etiquetas del eje y
    ax.get_yaxis().set_visible(False)

    # Añadir etiquetas a las barras
    for container in ax.containers:
        for i, bar in enumerate(container.patches):
            height = bar.get_height()
            if height > 0:  # Asegurarse de que hay un valor para mostrar
                label = f"$ {height / 1000:.0f}k"  # Formatear el valor en formato de miles
                x_position = bar.get_x() + bar.get_width() / 2
                y_position = bar.get_y() + height / 2
                ax.annotate(label,
                            xy=(x_position, y_position),
                            xytext=(0, 3),  # Distancia vertical desde el punto
                            textcoords="offset points",
                            ha='center', va='center',  # Colocar el texto en el centro
                            fontsize=8, fontweight='bold', color='white')  # Añadir negrita al texto

    # Configuracion del titulo
    ax.set_title('Ventas Totales por Año y Región\n(2019-2022)', loc='left', fontsize=15,  color='black')  # Mover el título a la izquierda

    # Rotar los años horizontalmente
    plt.xticks(rotation=0)

    # Mover la etiqueta de la región a la izquierda y ajustar la posición
    ax.legend(loc='upper right', bbox_to_anchor=(1.15, 1.0))

    # Texto debajo del gráfico
    texto = ("$\\mathbf{89.12\\%}$ \nde las ventas en el supermercado\n"
         "están concentradas en las regiones\n"
         "$\\mathbf{Sureste,}$ $\\mathbf{ Noreste}$ y\n"
         "$\\mathbf{Centro – }$ $\\mathbf{Oeste}$ desde el 2019")

    # Añadir texto y alinear a la izquierda
    ax.text(0.97, 0.38, texto, transform=ax.transAxes, ha='left', va='bottom', fontsize=13, color='blue')

    # Línea vertical de color azul
    ax.axvline(x=3.3, ymin=0.0, ymax=0.83, color='#00b4d8', linestyle='-', linewidth=2)

    # Ocultar todos los bordes del gráfico
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Quitar los ticks del eje X y Y
    ax.tick_params(axis='both', which='both', length=0)

    # Mostrar el gráfico
    plt.show()
pregunta_3()

# %% [markdown]
# ### 6. Pregunta 4: ¿Cuál es el método de envío más utilizado por los clientes del Supermercado? ¿Es proporcional para B2B y B2C?

# %% [markdown]
# ### 6.1 Creamos una copia de df_ventas_limpio y Guardamos solo las columnas modo_envio y segmento_cliente

# %%
# Creamos una copia de df_ventas_limpio
df_modo_envio = df_ventas_limpio.copy()
# Guardamos solo las columnas modo_envio y segmento_cliente
df_modo_envio = df_modo_envio[['modo_envio', 'segmento_cliente']]
df_modo_envio
# Out:
#             modo_envio segmento_cliente
# 0            Económico              B2C
# 1            Económico              B2C
# 2            Económico              B2B
# 3     Entrega estándar              B2C
# 4     Entrega estándar              B2C
# ...                ...              ...
# 7205  Entrega estándar              B2C
# 7206  Entrega estándar              B2B
# 7207  Entrega estándar              B2B
# 7208         Económico              B2C
# 7209         Económico              B2C
#
# [7210 rows x 2 columns]

# %% [markdown]
# ### 6.2 Generamos una tabla cruzada

# %%
# Generamos una tabla cruzada
df_modo_envio = pd.crosstab(index=df_modo_envio['modo_envio'], columns=df_modo_envio['segmento_cliente']).sort_values("B2B")
df_modo_envio
# Out:
# segmento_cliente   B2B   B2C
# modo_envio
# 24 horas           171   231
# Envío rápido       543   542
# Económico          707   755
# Entrega estándar  2048  2213

# %% [markdown]
# ### 6.3 Visualizacion

# %%
# calculamos el porcentaje de entrega estándar
porcentaje_entrega_estandar = (df_modo_envio['B2B'] + df_modo_envio['B2C']).loc['Entrega estándar'] / df_modo_envio[['B2B', 'B2C']].sum().sum() * 100

print(f"El método de entrega estándar representa el {porcentaje_entrega_estandar:.2f}% de los pedidos.")
# Out:
# El método de entrega estándar representa el 59.10% de los pedidos.

# %%
def pregunta_4():
    global df_ventas, df_ventas_limpio
        # Creamos una copia de df_ventas_limpio
    df_modo_envio = df_ventas_limpio.copy()
    # Guardamos solo las columnas modo_envio y segmento_cliente
    df_modo_envio = df_modo_envio[['modo_envio', 'segmento_cliente']]
    # Generamos una tabla cruzada
    df_modo_envio = pd.crosstab(index=df_modo_envio['modo_envio'], columns=df_modo_envio['segmento_cliente']).sort_values("B2B")
    
    # Visualizacion
    # Creamos una lista de colores
    colores = ['#0077b6', '#CDDBF3']

    # Crear la figura y el eje
    fig, ax = plt.subplots(figsize=(10, 4))

    # Crear el gráfico de barras horizontales
    bars_b2b = ax.barh(df_modo_envio.index, df_modo_envio['B2B'], color=colores[0])
    bars_b2c = ax.barh(df_modo_envio.index, df_modo_envio['B2C'], left=df_modo_envio['B2B'], color=colores[1])

    # Añadir etiquetas dentro de cada barra
    for bar in bars_b2b:
        label_x_position = bar.get_x() + bar.get_width() / 2
        label_y_position = bar.get_y() + bar.get_height() / 2
        label_value = f"{bar.get_width():.0f}"
        ax.text(label_x_position, label_y_position, label_value, 
                ha='center', va='center', color='white', fontsize=8, fontweight='bold')

    for bar in bars_b2c:
        label_x_position = bar.get_x() + bar.get_width() / 2
        label_y_position = bar.get_y() + bar.get_height() / 2
        label_value = f"{bar.get_width():.0f}"
        ax.text(label_x_position, label_y_position, label_value, 
                ha='center', va='center', color='white', fontsize=8, fontweight='bold')

    # Configuracion del titulo
    ax.set_title('Metodo de envío mas utilizado por los cliente B2B/B2C (2019-1022)\nEn valores absolutos', loc='center', fontsize=15, color='black')


    #leyenda con el valor de segmentos de clientes
    ax.text(0, 3.5, 'B2B|', fontsize=12, fontweight='bold', color=colores[0])
    ax.text(270, 3.5, 'B2C', fontsize=12, fontweight='bold', color=colores[1])



    # Ocultar todos los bordes del gráfico
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Quitar etiquetas del eje x
    ax.set_xticks([])
    
    # Texto $\\mathbf{2022}$
    texto = ("La $\\mathbf{entrega estandar}$ es el\n"
             "metodo de envio preferido por\n"
            "los clientes del supermercado,\n"
            "representa $\\mathbf{59.10\\%}$ de los pedidos,\n"
            "no hay diferencias entre segmentos\n"

                )


    # Añadir texto y alinear 
    ax.text(1.0, 0.35, texto, transform=ax.transAxes, ha='left', va='bottom', fontsize=14, color='blue')

    

    # Mostrar el gráfico
    plt.show()
    
pregunta_4()

# %% [markdown]
# ## 7 Pregunta 5: ¿Cuáles son las ventas totales por trimestre en el estado de São Paulo?

# %% [markdown]
# ### 7.1 Creamos una copia y filtramos los registros, seleccionamos las columnas fecha_pedido y total_venta y establecemos la columna fecha_pedido como índice

# %%
# Creamos una copia y filtramos los registros
df_ventas_sp = df_ventas_limpio[df_ventas_limpio['estado'] == 'São Paulo'].copy()

# Seleccionamos las columnas fecha_pedido y total_venta
df_ventas_sp = df_ventas_sp[['fecha_pedido', 'total_venta']]

# Establecemos la columna fecha_pedido como índice
df_ventas_sp.set_index('fecha_pedido', inplace=True)

df_ventas_sp.head()
# Out:
#               total_venta
# fecha_pedido
# 2021-11-09         890.66
# 2021-11-09        2488.59
# 2019-11-12        2263.98
# 2022-09-11         500.36
# 2019-10-21         720.64

# %%
df_ventas_sp.dtypes
# Out:
# total_venta    float64
# dtype: object

# %% [markdown]
# ### 7.2 Con resample agrupamos las ventas por trimestre ('Q') y sumamos los valores en forma trimestral

# %%
# agrupamos las ventas por trimestre ('Q') y sumamos los valores en forma trimestral
# df_ventas_sp['total_venta'] = pd.to_numeric(df_ventas_sp['total_venta'], errors='coerce')
df_ventas_sp['total_venta'] = pd.to_numeric(df_ventas_sp['total_venta'], errors='coerce')

# Agrupa las ventas por trimestre y suma los valores
df_ventas_sp = df_ventas_sp.resample('Q').agg('sum')
df_ventas_sp
# Out:
#               total_venta
# fecha_pedido
# 2019-03-31       27377.18
# 2019-06-30       33951.90
# 2019-09-30       90208.89
# 2019-12-31      124093.79
# 2020-03-31       26732.22
# 2020-06-30       66150.54
# 2020-09-30      109179.83
# 2020-12-31      180421.18
# 2021-03-31       35740.45
# 2021-06-30       95443.61
# 2021-09-30      119422.82
# 2021-12-31      236502.75
# 2022-03-31       61785.08
# 2022-06-30       74727.59
# 2022-09-30      144519.71
# 2022-12-31      307359.21

# %%
df_ventas_sp.dtypes
# Out:
# total_venta    float64
# dtype: object

# %% [markdown]
# ### 7.3 Redondear la columna total_venta a la escala de miles

# %%
# Redondear la columna total_venta a la escala de miles
df_ventas_sp['total_venta'] = df_ventas_sp['total_venta'].round()

# Formatear la columna total_venta para mostrarla en miles con dos decimales
df_ventas_sp['total_venta'] = df_ventas_sp['total_venta'].apply(lambda x: f'{x/1000:.2f}')

df_ventas_sp
# Out:
#              total_venta
# fecha_pedido
# 2019-03-31         27.38
# 2019-06-30         33.95
# 2019-09-30         90.21
# 2019-12-31        124.09
# 2020-03-31         26.73
# 2020-06-30         66.15
# 2020-09-30        109.18
# 2020-12-31        180.42
# 2021-03-31         35.74
# 2021-06-30         95.44
# 2021-09-30        119.42
# 2021-12-31        236.50
# 2022-03-31         61.78
# 2022-06-30         74.73
# 2022-09-30        144.52
# 2022-12-31        307.36

# %%
# Convertir la columna total_venta a tipo numérico
df_ventas_sp['total_venta'] = pd.to_numeric(df_ventas_sp['total_venta'])

# %%
df_ventas_sp.dtypes
# Out:
# total_venta    float64
# dtype: object

# %% [markdown]
# ### 7.4 eliminamos el índice existente y creamos uno nuevo, el parámetro drop=True evita que se agregue una columna adicional con el índice anterior

# %%
# Restablecer el índice y mantener la columna 'fecha_pedido'
df_ventas_sp = df_ventas_sp.reset_index()
df_ventas_sp
# Out:
#    fecha_pedido  total_venta
# 0    2019-03-31        27.38
# 1    2019-06-30        33.95
# 2    2019-09-30        90.21
# 3    2019-12-31       124.09
# 4    2020-03-31        26.73
# 5    2020-06-30        66.15
# 6    2020-09-30       109.18
# 7    2020-12-31       180.42
# 8    2021-03-31        35.74
# 9    2021-06-30        95.44
# 10   2021-09-30       119.42
# 11   2021-12-31       236.50
# 12   2022-03-31        61.78
# 13   2022-06-30        74.73
# 14   2022-09-30       144.52
# 15   2022-12-31       307.36

# %% [markdown]
# ### 7.5 Visualizacion

# %%
def pregunta5(): 
    
    global df_ventas, df_ventas_limpio
    
    # Creamos una copia y filtramos los registros
    df_ventas_sp = df_ventas_limpio[df_ventas_limpio['estado'] == 'São Paulo'].copy()
    
    # Seleccionamos las columnas fecha_pedido y total_venta
    df_ventas_sp = df_ventas_sp[['fecha_pedido', 'total_venta']]
    
    # Establecemos la columna fecha_pedido como índice
    df_ventas_sp.set_index('fecha_pedido', inplace=True)
    
    # agrupamos las ventas por trimestre ('Q') y sumamos los valores en forma trimestral
    df_ventas_sp['total_venta'] = pd.to_numeric(df_ventas_sp['total_venta'], errors='coerce')
    
    # Agrupa las ventas por trimestre y suma los valores
    df_ventas_sp = df_ventas_sp.resample('Q').agg('sum')
    
    # Redondear la columna total_venta a la escala de miles
    df_ventas_sp['total_venta'] = df_ventas_sp['total_venta'].round()
    
    # Formatear la columna total_venta para mostrarla en miles con dos decimales
    df_ventas_sp['total_venta'] = df_ventas_sp['total_venta'].apply(lambda x: f'{x/1000:.2f}')

    # Convertir la columna total_venta a tipo numérico
    df_ventas_sp['total_venta'] = pd.to_numeric(df_ventas_sp['total_venta'])
    # Restablecer el índice y mantener la columna 'fecha_pedido'
    df_ventas_sp = df_ventas_sp.reset_index()

    
    # Configuración de la figura y el eje
    fig, ax = plt.subplots(figsize=(14, 4))
        
    # Crear el gráfico de líneas
    puntos_a_marcar = [False, False, False, True, False, False, False, True, False, False, False, True, False, False, False, True]
    ax.plot(df_ventas_sp.index, df_ventas_sp['total_venta'], marker="o", markersize=8,  markevery=puntos_a_marcar,color='#3498db', linewidth=3)
        
    # Reemplazar las fechas en el eje X por el nombre del mes
    x_labels = ["Mar", "Jun", "Set", "Dic"] * 4
    ax.set_xticks(df_ventas_sp.index)
    ax.set_xticklabels(x_labels, ha="center")
        
    # Colocar valores solo en el 4to Trimestre
    for i in range(3, len(df_ventas_sp), 4):
        max_value = df_ventas_sp['total_venta'][i:i+4].max()
        max_index = df_ventas_sp['total_venta'][i:i+4].idxmax()
        ax.text(max_index, max_value + 15, f"${max_value:,.2f}", ha='left')
        
    # Configuramos el titulo
    ax.set_title('Ventas Trimestrales (2019-2022)',fontsize=14, color='black')
    #ax.set_xlabel('Trimestre')
    #ax.set_ylabel('Total de Ventas ($)')
        
    # Ocultar todos los bordes del gráfico
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)
        
        
    # Ocultar etiquetas del eje y
    ax.set_yticks([])
        
    # Texto 
    texto = ("|               2019          |                  2020               |                  2021              |                  2022                 |")
        
    # Añadir texto y alinear 
    ax.text(0.03, -0.2, texto, transform=ax.transAxes, ha='left', va='bottom', fontsize=14, color='black')
        
    # Mostrar el gráfico
    plt.show()

# Llamar a la función
pregunta5()

# %% [markdown]
# **Se puede obserbar claramente un crecimiento trimestral constante.
# Las ventas alcanzaron su punto más alto en el último trimestre del año 2022, destacando un aumento significativo en comparación con los años anteriores.**

# %% [markdown]
# ## 6. ¿Que cliente gasto mas?

# %%
# agrupamos por el nombre del cliente y sumamos el valor de la venta
compras_por_cliente = df_ventas_limpio.groupby('nombre_cliente')['total_venta'].sum().reset_index()

# ordenamos en orden descendente 
compras_por_cliente = compras_por_cliente.sort_values(by='total_venta', ascending=False)

compras_por_cliente
# Out:
#             nombre_cliente  total_venta
# 530    Maria Luiza Almeida     64688.96
# 42         Ana Julia Pinto     51360.53
# 515  Maria Clara Gonçalves     46659.86
# 683            Ryan Farias     45863.75
# 291         Heitor da Mata     44947.18
# ..                     ...          ...
# 1          Agatha Carvalho        49.72
# 497          Marcelo Ramos        47.73
# 46         Ana Júlia Moura        33.40
# 297      Henrique Caldeira        22.84
# 481      Luiz Otávio Viana        18.03
#
# [763 rows x 2 columns]

# %% [markdown]
# ### Top 10 Clientes que Más Han Gastado

# %%
def pregunta6():
    global df_ventas, df_ventas_limpio
    # Agrupamos por el nombre del cliente y sumamos el valor de la venta
    compras_por_cliente = df_ventas_limpio.groupby('nombre_cliente')['total_venta'].sum().reset_index()

    # Ordenamos en orden descendente 
    compras_por_cliente = compras_por_cliente.sort_values(by='total_venta', ascending=False)

    # Seleccionamos los 10 primeros clientes
    top_10_clientes = compras_por_cliente.head(10)

    # Creamos una lista de colores
    colores = ['#0077b6', '#0077b6', '#0077b6', '#0077b6', '#adb5bd', '#0C8040', '#0C8040', '#0C8040', '#0C8040', '#0C8040']

    # Graficamos
    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.bar(top_10_clientes['nombre_cliente'], top_10_clientes['total_venta'], color=colores)

    # Agregamos los valores en las barras
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f"${round(yval, 2)}", ha='center', va='bottom')

    #plt.xlabel('Clientes')
    #plt.ylabel('Total de Ventas')
    plt.title('Top 10 Clientes que Más Han Gastado', fontsize=14, color='black')

    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

    # Ocultar todos los bordes del gráfico
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Ocultar etiquetas del eje y
    ax.set_yticks([])

    plt.show()
pregunta6()

# %% [markdown]
# ## Top 10 clientes que menos han gastado

# %%
# agrupamos por el nombre del cliente y sumamos el valor de la venta
compras_por_cliente_menos = df_ventas_limpio.groupby('nombre_cliente')['total_venta'].sum().reset_index()

# ordenamos en orden descendente 
compras_por_cliente_menos = compras_por_cliente_menos.sort_values(by='total_venta',  ascending=True)

compras_por_cliente_menos
# Out:
#             nombre_cliente  total_venta
# 481      Luiz Otávio Viana        18.03
# 297      Henrique Caldeira        22.84
# 46         Ana Júlia Moura        33.40
# 497          Marcelo Ramos        47.73
# 1          Agatha Carvalho        49.72
# ..                     ...          ...
# 291         Heitor da Mata     44947.18
# 683            Ryan Farias     45863.75
# 515  Maria Clara Gonçalves     46659.86
# 42         Ana Julia Pinto     51360.53
# 530    Maria Luiza Almeida     64688.96
#
# [763 rows x 2 columns]

# %%
def pregunta6_menos_gastaron():
    global df_ventas, df_ventas_limpio
    
    # Agrupamos por el nombre del cliente y sumamos el valor de la venta
    compras_por_cliente = df_ventas_limpio.groupby('nombre_cliente')['total_venta'].sum().reset_index()

    # Ordenamos en orden ascendente para obtener los que menos gastaron
    compras_por_cliente = compras_por_cliente.sort_values(by='total_venta', ascending=True)

    # Seleccionamos los 10 primeros clientes (los que menos gastaron)
    bottom_10_clientes = compras_por_cliente.head(10)

    # Creamos una lista de colores 
    #colores = ['#adb5bd'] * 10  # usamos un solo color 
    colores = ['#1A1A1A', '#353535', '#515151', '#6C6C6C', '#878787', '#A2A2A2', '#BDBDBD', '#BDBDBD', '#BDBDBD', '#BDBDBD']

    # Graficamos
    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.bar(bottom_10_clientes['nombre_cliente'], bottom_10_clientes['total_venta'], color=colores)

    # Agregamos los valores en las barras
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, f"${round(yval, 2)}", ha='center', va='bottom')

    #plt.xlabel('Clientes')
    #plt.ylabel('Total de Ventas')
    plt.title('Top 10 Clientes que Menos Han Gastado', fontsize=14, color='black')

    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

    # Ocultar todos los bordes del gráfico
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Ocultar etiquetas del eje y
    ax.set_yticks([])

    plt.show()

# Llamar a la función
pregunta6_menos_gastaron()

# %% [markdown]
# **Estos clientes con menor gasto se puede tomar como oportunidades de mejora:**
#
#
# - **Incentivos personalizados:** Podría ser interesante ofrecer a estos clientes promociones o descuentos exclusivos para motivarlos a realizar compras adicionales.
# - **Análisis de comportamiento:** Se podría investigar si estos clientes tienen algo en común, como patrones de compra, productos favoritos o incluso restricciones geográficas. Esto ayudaría a diseñar campañas más efectivas.
# - **Fidelización:** El objetivo debe ser aumentar el compromiso de estos clientes con la marca, ofreciéndoles, por ejemplo, beneficios de fidelización o programas de referidos.
#
#
# Este grupo de clientes representa una oportunidad para el negocio de expandir su base de ingresos, aprovechando su potencial de crecimiento. Estudios de marketing relacional sugieren que convertir clientes de bajo valor en clientes recurrentes puede ser más rentable que adquirir nuevos clientes.
